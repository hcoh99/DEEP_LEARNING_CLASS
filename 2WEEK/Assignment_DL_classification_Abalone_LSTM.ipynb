# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## CSV파일 로드

# %%
df = pd.read_csv("/Users/ohheungchan/workspace/AI_Study/abalone.csv", index_col=0)
df
# Out:
#      Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  \
# id
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera_weight  Shell_weight  Rings
# id
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# 3             0.1140        0.1550     10
# 4             0.0395        0.0550      7
# ...              ...           ...    ...
# 4172          0.2390        0.2490     11
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4175          0.2610        0.2960     10
# 4176          0.3765        0.4950     12
#
# [4177 rows x 9 columns]

# %% [markdown]
# ## 결측치 확인

# %%
df.isnull().sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole_weight      0
# Shucked_weight    0
# Viscera_weight    0
# Shell_weight      0
# Rings             0
# dtype: int64

# %% [markdown]
# ## 이상치 확인

# %%
# 수치형 데이터 열만 선택
numeric_columns = df.select_dtypes(include=['float64', 'int64']).columns

# 박스플롯을 그리기 위한 설정
plt.figure(figsize=(15, 10))

# 각 변수에 대해 개별 박스플롯을 그립니다.
for i, column in enumerate(numeric_columns, 1):
    plt.subplot(3, 3, i)  # 3x3 grid로 subplot을 설정
    df.boxplot(column)
    plt.title(f'Boxplot of {column}')

# 레이아웃을 자동으로 조정하여 겹치지 않게 함
plt.tight_layout()

# 플롯을 출력
plt.show()

# %% [markdown]
# ### 컬럼 설명
#
# 1. **Sex**: 전복의 성별 (M: 수컷, F: 암컷, I: 새끼)
# 2. **Length**: 전복의 최대 길이 (밀리미터 단위)
# 3. **Diameter**: 전복의 지름, 길이에 수직인 측정치 (밀리미터 단위)
# 4. **Height**: 전복의 높이, 껍질 속 고기 포함 (밀리미터 단위)
# 5. **Whole weight**: 전복 전체의 무게 (그램 단위)
# 6. **Shucked weight**: 전복 고기의 무게 (그램 단위)
# 7. **Viscera weight**: 전복의 내장 무게, 출혈 후 측정 (그램 단위)
# 8. **Shell weight**: 건조 후 전복 껍질의 무게 (그램 단위)
# 9. **Rings**: 전복의 고리 수, 나이 추정의 기준 (+1.5년)

# %%
df.info
# Out:
# <bound method DataFrame.info of      Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  \
# id
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera_weight  Shell_weight  Rings
# id
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# 3             0.1140        0.1550     10
# 4             0.0395        0.0550      7
# ...              ...           ...    ...
# 4172          0.2390        0.2490     11
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4175          0.2610        0.2960     10
# 4176          0.3765        0.4950     12
#
# [4177 rows x 9 columns]>

# %%
df.columns
# Out:
# Index(['Sex', 'Length', 'Diameter', 'Height', 'Whole_weight', 'Shucked_weight',
#        'Viscera_weight', 'Shell_weight', 'Rings'],
#       dtype='object')

# %% [markdown]
# ### 인코딩 (문자->수치)

# %%
# 'Sex'컬럼의 F/M을 수치화
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()
df['Sex'] = label.fit_transform(df['Sex'])

# %% [markdown]
# (M->0, F->2, I->1)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# 카운트플롯 그리기
plt.figure(figsize=(10, 6))
sns.countplot(x='Rings', data=df, palette='Set3')
plt.title('Count of Each Rings Value', fontsize=16)
plt.xlabel('Rings', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.xticks(rotation=45)  # x축 값이 겹치지 않도록 회전
plt.show()
# Out:
# /var/folders/9x/8whwzmnj6z5bjc7_h1txd9_r0000gn/T/ipykernel_85395/2749004283.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Rings', data=df, palette='Set3')

# %% [markdown]
# ## 각 피쳐간의 상관관계를 확인.

# %%
df_corr=df.corr()

#히트맵
plt.figure(figsize=(10,10))
sns.set(font_scale=0.8)
sns.heatmap(df_corr, annot=True, cbar=False)
plt.show()

# %%
y = df["Rings"]
y
# Out:
# id
# 0       15
# 1        7
# 2        9
# 3       10
# 4        7
#         ..
# 4172    11
# 4173    10
# 4174     9
# 4175    10
# 4176    12
# Name: Rings, Length: 4177, dtype: int64

# %% [markdown]
# ## label값을 구간화
# - 연속데이터를 범주형으로 바꾸는 작업

# %%
print (df.columns)
df = df.drop(columns=['Sex']) # Sex 특성 제거

for ix in df.index :
    row = df.loc[ix]
    if row.Rings <= 8:
        df.loc[ix, 'Rings'] = 'young'
    elif row.Rings >= 11:
        df.loc[ix, 'Rings'] = 'old'
    elif row.Rings >=9 & row.Rings <= 10:
        df.loc[ix, 'Rings'] = 'medium'
        
df.head()
# Out:
# Index(['Sex', 'Length', 'Diameter', 'Height', 'Whole_weight', 'Shucked_weight',
#        'Viscera_weight', 'Shell_weight', 'Rings'],
#       dtype='object')
# /var/folders/9x/8whwzmnj6z5bjc7_h1txd9_r0000gn/T/ipykernel_85395/3874682361.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'old' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[ix, 'Rings'] = 'old'
#     Length  Diameter  Height  Whole_weight  Shucked_weight  Viscera_weight  \
# id
# 0    0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1    0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2    0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3    0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4    0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#     Shell_weight   Rings
# id
# 0          0.150     old
# 1          0.070   young
# 2          0.210  medium
# 3          0.155  medium
# 4          0.055   young

# %%
plt.bar("young", len(df[df['Rings'] == 'young']), label="young")
plt.bar("medium", len(df[df['Rings'] == 'medium']), label="medium")
plt.bar("old", len(df[df['Rings'] == 'old']), label="old")
plt.legend()
plt.show()

# %%
y = df['Rings']
y
# Out:
# id
# 0          old
# 1        young
# 2       medium
# 3       medium
# 4        young
#          ...
# 4172       old
# 4173    medium
# 4174    medium
# 4175    medium
# 4176       old
# Name: Rings, Length: 4177, dtype: object

# %%
x = df.drop("Rings" , axis = 1)
x
# Out:
#       Length  Diameter  Height  Whole_weight  Shucked_weight  Viscera_weight  \
# id
# 0      0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1      0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2      0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3      0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4      0.330     0.255   0.080        0.2050          0.0895          0.0395
# ...      ...       ...     ...           ...             ...             ...
# 4172   0.565     0.450   0.165        0.8870          0.3700          0.2390
# 4173   0.590     0.440   0.135        0.9660          0.4390          0.2145
# 4174   0.600     0.475   0.205        1.1760          0.5255          0.2875
# 4175   0.625     0.485   0.150        1.0945          0.5310          0.2610
# 4176   0.710     0.555   0.195        1.9485          0.9455          0.3765
#
#       Shell_weight
# id
# 0           0.1500
# 1           0.0700
# 2           0.2100
# 3           0.1550
# 4           0.0550
# ...            ...
# 4172        0.2490
# 4173        0.2605
# 4174        0.3080
# 4175        0.2960
# 4176        0.4950
#
# [4177 rows x 7 columns]

# %%
print(x.shape)
print(y.shape)
# Out:
# (4177, 7)
# (4177,)

# %%
import numpy as np

np.unique(y)
# Out:
# array(['medium', 'old', 'young'], dtype=object)

# %%
y.shape
# Out:
# (4177,)

# %% [markdown]
# ## split_sequence
# - 각 타임스텝에서 가장 빈번하게 나온 label을 해당 타임스텝의 label로 설정.

# %%
import numpy as np
from collections import Counter

# split_sequence 함수 
def split_sequence(sequence, labels, n_steps):
    X, y = list(), list()
    for i in range(len(sequence)):
        end_ix = i + n_steps
        if end_ix > len(sequence)-1:
            break
        
        # sequence에서 n_steps 크기만큼 데이터 추출
        seq_x = sequence[i:end_ix]
        
        # labels에서 n_steps 크기만큼 레이블 추출
        seq_y = labels[i:end_ix]
        
        # seq_y에서 가장 많이 등장한 레이블 선택
        most_common_label = Counter(seq_y).most_common(1)[0][0]
        
        # X와 y에 추가
        X.append(seq_x)
        y.append(most_common_label)
    
    return np.array(X), np.array(y)

# %%
# n_step 값 정의
n_step = 7

# X과 y을 시퀀스 형태로 변환
X, y = split_sequence(x,y,n_step)
print(f" data shape: {X.shape}, Labels shape: {y.shape}")
# Out:
#  data shape: (4170, 7, 7), Labels shape: (4170,)

# %%
print(y)
# Out:
# ['young' 'young' 'medium' ... 'medium' 'medium' 'medium']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=32)

X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, stratify=y_train, random_state=32)

X_train.shape, X_test.shape, y_train.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((2668, 7, 7), (834, 7, 7), (2668,), (834,), (668, 7, 7), (668,))

# %%
label_encoder = LabelEncoder()
y_train_encoded = label_encoder.fit_transform(y_train)
y_val_encoded = label_encoder.transform(y_val)
y_test_encoded = label_encoder.transform(y_test)

# %%
from tensorflow.keras.utils import to_categorical

trainy_one_hot = to_categorical(y_train_encoded)
val_one_hot = to_categorical(y_val_encoded)
testy_one_hot = to_categorical(y_test_encoded)

# %%
n_timesteps, n_features = X_train.shape[1], X_train.shape[2]

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout

# LSTM 모델 정의
model = Sequential()

# 첫 번째 LSTM 레이어, return_sequences=True로 설정
model.add(LSTM(64, return_sequences=True, input_shape=(n_timesteps, n_features)))
model.add(Dropout(0.5))

# 두 번째 LSTM 레이어, return_sequences=False (기본값)로 설정
model.add(LSTM(64))
model.add(Dropout(0.5))

# Dense 레이어로 출력
model.add(Dense(16, activation='relu'))
model.add(Dense(3, activation='softmax'))  # 다중 분류를 위한 softmax 출력

# 모델 컴파일
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# 모델 요약
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_5 (LSTM)               (None, 7, 64)             18432
#
#  dropout_1 (Dropout)         (None, 7, 64)             0
#
#  lstm_6 (LSTM)               (None, 64)                33024
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 16)                1040
#
#  dense_3 (Dense)             (None, 3)                 51
#
# =================================================================
# Total params: 52,547
# Trainable params: 52,547
# Non-trainable params: 0
# _________________________________________________________________

# %%
batch_size = 16

train_epochs = 50
history = model.fit(X_train, trainy_one_hot, epochs=train_epochs, batch_size=batch_size, validation_data=(X_val, val_one_hot), verbose=True, shuffle=True)
# Out:
# Epoch 1/50
# 2024-09-26 10:15:04.456758: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2024-09-26 10:15:04.695185: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2024-09-26 10:15:04.872190: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2024-09-26 10:15:05.082202: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2024-09-26 10:15:05.279345: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 167/167 [==============================] - ETA: 0s - loss: 0.9982 - accuracy: 0.4539
# 2024-09-26 10:15:10.452509: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2024-09-26 10:15:10.538615: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2024-09-26 10:15:10.628475: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 167/167 [==============================] - 8s 36ms/step - loss: 0.9982 - accuracy: 0.4539 - val_loss: 0.8908 - val_accuracy: 0.5000
# Epoch 2/50
# 167/167 [==============================] - 5s 28ms/step - loss: 0.8853 - accuracy: 0.5510 - val_loss: 0.7778 - val_accuracy: 0.6587
# Epoch 3/50
# 167/167 [==============================] - 5s 28ms/step - loss: 0.7832 - accuracy: 0.6484 - val_loss: 0.8041 - val_accuracy: 0.5749
# Epoch 4/50
# 167/167 [==============================] - 5s 28ms/step - loss: 0.7083 - accuracy: 0.6912 - val_loss: 0.6435 - val_accuracy: 0.7216
# Epoch 5/50
# 167/167 [==============================] - 5s 28ms/step - loss: 0.6737 - accuracy: 0.7058 - val_loss: 0.6089 - val_accuracy: 0.7290
# Epoch 6/50
# 167/167 [==============================] - 5s 28ms/step - loss: 0.6523 - accuracy: 0.7144 - val_loss: 0.5922 - val_accuracy: 0.7320
# Epoch 7/50
# 167/167 [==============================] - 5s 29ms/step - loss: 0.6242 - accuracy: 0.7226 - val_loss: 0.5999 - val_accuracy: 0.7320
# Epoch 8/50
# 167/167 [==============================] - 5s 29ms/step - loss: 0.6360 - accuracy: 0.7189 - val_loss: 0.5788 - val_accuracy: 0.7425
# Epoch 9/50
# 167/167 [==============================] - 5s 29ms/step - loss: 0.6259 - accuracy: 0.7346 - val_loss: 0.5626 - val_accuracy: 0.7635
# Epoch 10/50
# 167/167 [==============================] - 5s 29ms/step - loss: 0.6288 - accuracy: 0.7245 - val_loss: 0.5882 - val_accuracy: 0.7455
# Epoch 11/50
# 167/167 [==============================] - 5s 29ms/step - loss: 0.6100 - accuracy: 0.7196 - val_loss: 0.5647 - val_accuracy: 0.7590
# Epoch 12/50
# 167/167 [==============================] - 5s 29ms/step - loss: 0.5953 - accuracy: 0.7388 - val_loss: 0.5639 - val_accuracy: 0.7575
# Epoch 13/50
# 167/167 [==============================] - 5s 28ms/step - loss: 0.6069 - accuracy: 0.7290 - val_loss: 0.5774 - val_accuracy: 0.7500
# Epoch 14/50
# 167/167 [==============================] - 5s 29ms/step - loss: 0.5980 - accuracy: 0.7335 - val_loss: 0.5558 - val_accuracy: 0.7635
# Epoch 15/50
# 167/167 [==============================] - 5s 29ms/step - loss: 0.5903 - accuracy: 0.7316 - val_loss: 0.5478 - val_accuracy: 0.7635
# Epoch 16/50
# 167/167 [==============================] - 5s 28ms/step - loss: 0.5855 - accuracy: 0.7421 - val_loss: 0.5545 - val_accuracy: 0.7530
# Epoch 17/50
# 167/167 [==============================] - 5s 29ms/step - loss: 0.5733 - accuracy: 0.7436 - val_loss: 0.5979 - val_accuracy: 0.7605
# Epoch 18/50
# 167/167 [==============================] - 5s 29ms/step - loss: 0.5849 - accuracy: 0.7421 - val_loss: 0.5441 - val_accuracy: 0.7635
# Epoch 19/50
# 167/167 [==============================] - 5s 29ms/step - loss: 0.5738 - accuracy: 0.7384 - val_loss: 0.5522 - val_accuracy: 0.7515
# Epoch 20/50
# 167/167 [==============================] - 5s 30ms/step - loss: 0.5718 - accuracy: 0.7421 - val_loss: 0.5438 - val_accuracy: 0.7605
# Epoch 21/50
# 167/167 [==============================] - 5s 30ms/step - loss: 0.5801 - accuracy: 0.7373 - val_loss: 0.5869 - val_accuracy: 0.7425
# Epoch 22/50
# 167/167 [==============================] - 5s 29ms/step - loss: 0.5654 - accuracy: 0.7567 - val_loss: 0.5470 - val_accuracy: 0.7470
# Epoch 23/50
# 167/167 [==============================] - 5s 30ms/step - loss: 0.5752 - accuracy: 0.7470 - val_loss: 0.5981 - val_accuracy: 0.7485
# Epoch 24/50
# 167/167 [==============================] - 5s 29ms/step - loss: 0.5705 - accuracy: 0.7399 - val_loss: 0.5598 - val_accuracy: 0.7725
# Epoch 25/50
# 167/167 [==============================] - 5s 29ms/step - loss: 0.5673 - accuracy: 0.7429 - val_loss: 0.5670 - val_accuracy: 0.7455
# Epoch 26/50
# 167/167 [==============================] - 5s 29ms/step - loss: 0.5624 - accuracy: 0.7403 - val_loss: 0.5591 - val_accuracy: 0.7605
# Epoch 27/50
# 167/167 [==============================] - 5s 29ms/step - loss: 0.5548 - accuracy: 0.7500 - val_loss: 0.5252 - val_accuracy: 0.7650
# Epoch 28/50
# 167/167 [==============================] - 5s 29ms/step - loss: 0.5703 - accuracy: 0.7433 - val_loss: 0.5546 - val_accuracy: 0.7665
# Epoch 29/50
# 167/167 [==============================] - 5s 28ms/step - loss: 0.5597 - accuracy: 0.7552 - val_loss: 0.5308 - val_accuracy: 0.7665
# Epoch 30/50
# 167/167 [==============================] - 5s 29ms/step - loss: 0.5616 - accuracy: 0.7470 - val_loss: 0.5906 - val_accuracy: 0.7620
# Epoch 31/50
# 167/167 [==============================] - 5s 28ms/step - loss: 0.5458 - accuracy: 0.7534 - val_loss: 0.5419 - val_accuracy: 0.7605
# Epoch 32/50
# 167/167 [==============================] - 5s 29ms/step - loss: 0.5494 - accuracy: 0.7549 - val_loss: 0.5405 - val_accuracy: 0.7710
# Epoch 33/50
# 167/167 [==============================] - 5s 29ms/step - loss: 0.5533 - accuracy: 0.7511 - val_loss: 0.5416 - val_accuracy: 0.7560
# Epoch 34/50
# 167/167 [==============================] - 5s 29ms/step - loss: 0.5487 - accuracy: 0.7504 - val_loss: 0.5415 - val_accuracy: 0.7710
# Epoch 35/50
# 167/167 [==============================] - 5s 29ms/step - loss: 0.5505 - accuracy: 0.7511 - val_loss: 0.5258 - val_accuracy: 0.7710
# Epoch 36/50
# 167/167 [==============================] - 5s 28ms/step - loss: 0.5473 - accuracy: 0.7511 - val_loss: 0.5359 - val_accuracy: 0.7710
# Epoch 37/50
# 167/167 [==============================] - 5s 29ms/step - loss: 0.5477 - accuracy: 0.7530 - val_loss: 0.5562 - val_accuracy: 0.7545
# Epoch 38/50
# 167/167 [==============================] - 5s 29ms/step - loss: 0.5366 - accuracy: 0.7582 - val_loss: 0.5250 - val_accuracy: 0.7650
# Epoch 39/50
# 167/167 [==============================] - 5s 29ms/step - loss: 0.5427 - accuracy: 0.7582 - val_loss: 0.5205 - val_accuracy: 0.7680
# Epoch 40/50
# 167/167 [==============================] - 5s 29ms/step - loss: 0.5388 - accuracy: 0.7534 - val_loss: 0.5315 - val_accuracy: 0.7740
# Epoch 41/50
# 167/167 [==============================] - 5s 28ms/step - loss: 0.5441 - accuracy: 0.7537 - val_loss: 0.5403 - val_accuracy: 0.7710
# Epoch 42/50
# 167/167 [==============================] - 5s 30ms/step - loss: 0.5346 - accuracy: 0.7515 - val_loss: 0.5503 - val_accuracy: 0.7740
# Epoch 43/50
# 167/167 [==============================] - 5s 28ms/step - loss: 0.5350 - accuracy: 0.7609 - val_loss: 0.5280 - val_accuracy: 0.7799
# Epoch 44/50
# 167/167 [==============================] - 5s 29ms/step - loss: 0.5421 - accuracy: 0.7571 - val_loss: 0.5326 - val_accuracy: 0.7754
# Epoch 45/50
# 167/167 [==============================] - 5s 29ms/step - loss: 0.5459 - accuracy: 0.7522 - val_loss: 0.5597 - val_accuracy: 0.7515
# Epoch 46/50
# 167/167 [==============================] - 5s 29ms/step - loss: 0.5329 - accuracy: 0.7620 - val_loss: 0.5665 - val_accuracy: 0.7665
# Epoch 47/50
# 167/167 [==============================] - 5s 30ms/step - loss: 0.5398 - accuracy: 0.7519 - val_loss: 0.5172 - val_accuracy: 0.7889
# Epoch 48/50
# 167/167 [==============================] - 5s 29ms/step - loss: 0.5233 - accuracy: 0.7639 - val_loss: 0.5235 - val_accuracy: 0.7725
# Epoch 49/50
# 167/167 [==============================] - 5s 29ms/step - loss: 0.5374 - accuracy: 0.7545 - val_loss: 0.5378 - val_accuracy: 0.7754
# Epoch 50/50
# 167/167 [==============================] - 5s 29ms/step - loss: 0.5307 - accuracy: 0.7575 - val_loss: 0.5234 - val_accuracy: 0.7814

# %%
import matplotlib.pyplot as plt
import seaborn as sns

loss =history.history['loss']
val_loss =history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
acc =history.history['accuracy']
val_acc =history.history['val_accuracy']
plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score
from sklearn.metrics import f1_score, classification_report
predy=model.predict(X_test)
predy=np.argmax(predy, axis=-1)
LABELS = ['Young', 'Midium', 'Old']
cm=confusion_matrix(y_test_encoded,predy)
print(cm)
print(accuracy_score(y_test_encoded,predy))
print(f1_score(y_test_encoded,predy, average='weighted'))
print(classification_report(y_test_encoded,predy))
sns.heatmap(cm, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt = '.2f')
# Out:
# 27/27 [==============================] - 0s 5ms/step
# [[165  58  30]
#  [ 48 248  15]
#  [ 44  18 208]]
# 0.7446043165467626
# 0.745071596237977
#               precision    recall  f1-score   support
#
#            0       0.64      0.65      0.65       253
#            1       0.77      0.80      0.78       311
#            2       0.82      0.77      0.80       270
#
#     accuracy                           0.74       834
#    macro avg       0.74      0.74      0.74       834
# weighted avg       0.75      0.74      0.75       834
# <Axes: >
