# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/Users/ohheungchan/workspace/AI_Study/abalone.csv")
df
# Out:
#         id Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  \
# 0        0   M   0.455     0.365   0.095        0.5140          0.2245
# 1        1   M   0.350     0.265   0.090        0.2255          0.0995
# 2        2   F   0.530     0.420   0.135        0.6770          0.2565
# 3        3   M   0.440     0.365   0.125        0.5160          0.2155
# 4        4   I   0.330     0.255   0.080        0.2050          0.0895
# ...    ...  ..     ...       ...     ...           ...             ...
# 4172  4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173  4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174  4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175  4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176  4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera_weight  Shell_weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# 3             0.1140        0.1550     10
# 4             0.0395        0.0550      7
# ...              ...           ...    ...
# 4172          0.2390        0.2490     11
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4175          0.2610        0.2960     10
# 4176          0.3765        0.4950     12
#
# [4177 rows x 10 columns]

# %% [markdown]
# ## 결측치 확인

# %%
df.isnull().sum()
# Out:
# id                0
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole_weight      0
# Shucked_weight    0
# Viscera_weight    0
# Shell_weight      0
# Rings             0
# dtype: int64

# %% [markdown]
# ## 이상치 확인

# %%
# 수치형 데이터 열만 선택
numeric_columns = df.select_dtypes(include=['float64', 'int64']).columns

# 박스플롯을 그리기 위한 설정
plt.figure(figsize=(15, 10))

# 각 변수에 대해 개별 박스플롯을 그립니다.
for i, column in enumerate(numeric_columns, 1):
    plt.subplot(3, 3, i)  # 3x3 grid로 subplot을 설정
    df.boxplot(column)
    plt.title(f'Boxplot of {column}')

# 레이아웃을 자동으로 조정하여 겹치지 않게 함
plt.tight_layout()

# 플롯을 출력
plt.show()

# %% [markdown]
# ### 컬럼 설명
#
# 1. **Sex**: 전복의 성별 (M: 수컷, F: 암컷, I: 새끼)
# 2. **Length**: 전복의 최대 길이 (밀리미터 단위)
# 3. **Diameter**: 전복의 지름, 길이에 수직인 측정치 (밀리미터 단위)
# 4. **Height**: 전복의 높이, 껍질 속 고기 포함 (밀리미터 단위)
# 5. **Whole weight**: 전복 전체의 무게 (그램 단위)
# 6. **Shucked weight**: 전복 고기의 무게 (그램 단위)
# 7. **Viscera weight**: 전복의 내장 무게, 출혈 후 측정 (그램 단위)
# 8. **Shell weight**: 건조 후 전복 껍질의 무게 (그램 단위)
# 9. **Rings**: 전복의 고리 수, 나이 추정의 기준 (+1.5년)

# %%
df.info
# Out:
# <bound method DataFrame.info of         id Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  \
# 0        0   M   0.455     0.365   0.095        0.5140          0.2245
# 1        1   M   0.350     0.265   0.090        0.2255          0.0995
# 2        2   F   0.530     0.420   0.135        0.6770          0.2565
# 3        3   M   0.440     0.365   0.125        0.5160          0.2155
# 4        4   I   0.330     0.255   0.080        0.2050          0.0895
# ...    ...  ..     ...       ...     ...           ...             ...
# 4172  4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173  4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174  4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175  4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176  4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera_weight  Shell_weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# 3             0.1140        0.1550     10
# 4             0.0395        0.0550      7
# ...              ...           ...    ...
# 4172          0.2390        0.2490     11
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4175          0.2610        0.2960     10
# 4176          0.3765        0.4950     12
#
# [4177 rows x 10 columns]>

# %%
df.columns
# Out:
# Index(['id', 'Sex', 'Length', 'Diameter', 'Height', 'Whole_weight',
#        'Shucked_weight', 'Viscera_weight', 'Shell_weight', 'Rings'],
#       dtype='object')

# %% [markdown]
# ### 인코딩 (문자->수치)

# %%
# 'Sex'컬럼의 F/M을 수치화
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()
df['Sex'] = label.fit_transform(df['Sex'])

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# 카운트플롯 그리기
plt.figure(figsize=(10, 6))
sns.countplot(x='Rings', data=df, palette='Set3')
plt.title('Count of Each Rings Value', fontsize=16)
plt.xlabel('Rings', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.xticks(rotation=45)  # x축 값이 겹치지 않도록 회전
plt.show()
# Out:
# /var/folders/9x/8whwzmnj6z5bjc7_h1txd9_r0000gn/T/ipykernel_56691/2749004283.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Rings', data=df, palette='Set3')

# %%
df_corr=df.corr()

#히트맵
plt.figure(figsize=(10,10))
sns.set(font_scale=0.8)
sns.heatmap(df_corr, annot=True, cbar=False)
plt.show()

# %%
y = df["Rings"]
y
# Out:
# 0       15
# 1        7
# 2        9
# 3       10
# 4        7
#         ..
# 4172    11
# 4173    10
# 4174     9
# 4175    10
# 4176    12
# Name: Rings, Length: 4177, dtype: int64

# %%
y.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0       15
# 1        7
# 2        9
# 3       10
# 4        7
#         ..
# 4172    11
# 4173    10
# 4174     9
# 4175    10
# 4176    12
# Name: Rings, Length: 4177, dtype: int64>

# %%
x = df.drop("Rings" , axis = 1)
x
# Out:
#         id  Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  \
# 0        0    2   0.455     0.365   0.095        0.5140          0.2245
# 1        1    2   0.350     0.265   0.090        0.2255          0.0995
# 2        2    0   0.530     0.420   0.135        0.6770          0.2565
# 3        3    2   0.440     0.365   0.125        0.5160          0.2155
# 4        4    1   0.330     0.255   0.080        0.2050          0.0895
# ...    ...  ...     ...       ...     ...           ...             ...
# 4172  4172    0   0.565     0.450   0.165        0.8870          0.3700
# 4173  4173    2   0.590     0.440   0.135        0.9660          0.4390
# 4174  4174    2   0.600     0.475   0.205        1.1760          0.5255
# 4175  4175    0   0.625     0.485   0.150        1.0945          0.5310
# 4176  4176    2   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera_weight  Shell_weight
# 0             0.1010        0.1500
# 1             0.0485        0.0700
# 2             0.1415        0.2100
# 3             0.1140        0.1550
# 4             0.0395        0.0550
# ...              ...           ...
# 4172          0.2390        0.2490
# 4173          0.2145        0.2605
# 4174          0.2875        0.3080
# 4175          0.2610        0.2960
# 4176          0.3765        0.4950
#
# [4177 rows x 9 columns]

# %%
print(x.shape)
print(y.shape)
# Out:
# (4177, 9)
# (4177,)

# %%
df.hist(bins=50, figsize=(12, 8))
# Out:
# array([[<Axes: title={'center': 'id'}>, <Axes: title={'center': 'Sex'}>,
#         <Axes: title={'center': 'Length'}>],
#        [<Axes: title={'center': 'Diameter'}>,
#         <Axes: title={'center': 'Height'}>,
#         <Axes: title={'center': 'Whole_weight'}>],
#        [<Axes: title={'center': 'Shucked_weight'}>,
#         <Axes: title={'center': 'Viscera_weight'}>,
#         <Axes: title={'center': 'Shell_weight'}>],
#        [<Axes: title={'center': 'Rings'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
# split_sequence 함수
def split_sequence(df, n_steps):
    X, y = [], []
    for i in range(len(df) - n_steps):
        seq_x = df.iloc[i:i+n_steps, :-1].values  # 마지막 열(Rings)을 제외한 특징들
        seq_y = df.iloc[i+n_steps, -1]  # Rings (예측할 값)
        X.append(seq_x)
        y.append(seq_y)
    return np.array(X), np.array(y)

# %%
n_steps = 7

X, y = split_sequence(df, n_steps)
print("입력 데이터 (X):", X)
print("출력 데이터 (y):", y)
# Out:
# 입력 데이터 (X): [[[0.000e+00 2.000e+00 4.550e-01 ... 2.245e-01 1.010e-01 1.500e-01]
#   [1.000e+00 2.000e+00 3.500e-01 ... 9.950e-02 4.850e-02 7.000e-02]
#   [2.000e+00 0.000e+00 5.300e-01 ... 2.565e-01 1.415e-01 2.100e-01]
#   ...
#   [4.000e+00 1.000e+00 3.300e-01 ... 8.950e-02 3.950e-02 5.500e-02]
#   [5.000e+00 1.000e+00 4.250e-01 ... 1.410e-01 7.750e-02 1.200e-01]
#   [6.000e+00 0.000e+00 5.300e-01 ... 2.370e-01 1.415e-01 3.300e-01]]
#


# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=32)

X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=32)

X_train.shape, X_test.shape, y_train.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((2668, 7, 9), (834, 7, 9), (2668,), (834,), (668, 7, 9), (668,))

# %%
n_timesteps, n_features = X_train.shape[1], X_train.shape[2]

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

model = Sequential()

# LSTM 레이어 추가
model.add(LSTM(50, activation='relu', input_shape=(n_timesteps, n_features), return_sequences=True))
model.add(LSTM(70, activation='relu',return_sequences=True))
model.add(LSTM(50, activation='relu'))

# 출력층
model.add(Dense(16, activation='relu'))
model.add(Dense(1, activation='linear'))  # 회귀 문제에서는 'linear' 활성화 함수 사용

# 컴파일 (회귀 문제이므로 MSE 사용)
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mean_squared_error'])

# 모델 요약
model.summary()
# Out:
# Metal device set to: Apple M2 Pro
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2024-09-30 18:11:46.318310: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-30 18:11:46.318457: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 7, 50)             12000
#
#  lstm_1 (LSTM)               (None, 7, 70)             33880
#
#  lstm_2 (LSTM)               (None, 50)                24200
#
#  dense (Dense)               (None, 16)                816
#
#  dense_1 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 70,913
# Trainable params: 70,913
# Non-trainable params: 0
# _________________________________________________________________

# %%
batch_size = 32

train_epochs = 40
history = model.fit(X_train, y_train, epochs=train_epochs, batch_size=batch_size, validation_data=(X_val, y_val), verbose=True, shuffle=True)
# Out:
# Epoch 1/40
# 2024-09-30 18:11:46.797381: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2024-09-30 18:11:48.129718: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 84/84 [==============================] - ETA: 0s - loss: 36.2241 - mean_squared_error: 36.2241
# 2024-09-30 18:12:11.620196: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 84/84 [==============================] - 26s 271ms/step - loss: 36.2241 - mean_squared_error: 36.2241 - val_loss: 13.2880 - val_mean_squared_error: 13.2880
# Epoch 2/40
# 84/84 [==============================] - 22s 262ms/step - loss: 200.5009 - mean_squared_error: 200.5009 - val_loss: 11.5932 - val_mean_squared_error: 11.5932
# Epoch 3/40
# 84/84 [==============================] - 22s 266ms/step - loss: 11.0110 - mean_squared_error: 11.0110 - val_loss: 9.7804 - val_mean_squared_error: 9.7804
# Epoch 4/40
# 84/84 [==============================] - 22s 261ms/step - loss: 10.5830 - mean_squared_error: 10.5830 - val_loss: 9.4237 - val_mean_squared_error: 9.4237
# Epoch 5/40
# 84/84 [==============================] - 21s 246ms/step - loss: 10.3604 - mean_squared_error: 10.3604 - val_loss: 9.0918 - val_mean_squared_error: 9.0918
# Epoch 6/40
# 84/84 [==============================] - 19s 232ms/step - loss: 10.4436 - mean_squared_error: 10.4436 - val_loss: 9.0818 - val_mean_squared_error: 9.0818
# Epoch 7/40
# 84/84 [==============================] - 19s 232ms/step - loss: 10.1897 - mean_squared_error: 10.1897 - val_loss: 10.4131 - val_mean_squared_error: 10.4131
# Epoch 8/40
# 84/84 [==============================] - 20s 234ms/step - loss: 10.5919 - mean_squared_error: 10.5919 - val_loss: 9.0913 - val_mean_squared_error: 9.0913
# Epoch 9/40
# 84/84 [==============================] - 20s 242ms/step - loss: 10.3116 - mean_squared_error: 10.3116 - val_loss: 11.6136 - val_mean_squared_error: 11.6136
# Epoch 10/40
# 84/84 [==============================] - 20s 234ms/step - loss: 10.1784 - mean_squared_error: 10.1784 - val_loss: 10.9109 - val_mean_squared_error: 10.9109
# Epoch 29/40
# 84/84 [==============================] - 20s 237ms/step - loss: 10.7671 - mean_squared_error: 10.7671 - val_loss: 9.4095 - val_mean_squared_error: 9.4095
# Epoch 30/40
# 84/84 [==============================] - 19s 232ms/step - loss: 10.1771 - mean_squared_error: 10.1771 - val_loss: 9.2674 - val_mean_squared_error: 9.2674
# Epoch 31/40
# 84/84 [==============================] - 20s 234ms/step - loss: 10.2619 - mean_squared_error: 10.2619 - val_loss: 11.0079 - val_mean_squared_error: 11.0079
# Epoch 32/40
# 84/84 [==============================] - 20s 234ms/step - loss: 9.9461 - mean_squared_error: 9.9461 - val_loss: 9.0598 - val_mean_squared_error: 9.0598
# Epoch 33/40
# 84/84 [==============================] - 20s 233ms/step - loss: 9.9492 - mean_squared_error: 9.9492 - val_loss: 9.2573 - val_mean_squared_error: 9.2573
# Epoch 34/40
# 84/84 [==============================] - 20s 232ms/step - loss: 10.2296 - mean_squared_error: 10.2296 - val_loss: 9.8307 - val_mean_squared_error: 9.8307
# Epoch 35/40
# 84/84 [==============================] - 21s 248ms/step - loss: 9.9905 - mean_squared_error: 9.9905 - val_loss: 9.2492 - val_mean_squared_error: 9.2492
# Epoch 36/40
# 84/84 [==============================] - 20s 235ms/step - loss: 9.8318 - mean_squared_error: 9.8318 - val_loss: 9.1910 - val_mean_squared_error: 9.1910
# Epoch 37/40
# 84/84 [==============================] - 20s 233ms/step - loss: 10.0716 - mean_squared_error: 10.0716 - val_loss: 9.6731 - val_mean_squared_error: 9.6731
# Epoch 38/40
# 84/84 [==============================] - 20s 239ms/step - loss: 9.8484 - mean_squared_error: 9.8484 - val_loss: 9.1062 - val_mean_squared_error: 9.1062
# Epoch 39/40
# 84/84 [==============================] - 20s 240ms/step - loss: 10.0142 - mean_squared_error: 10.0142 - val_loss: 9.2455 - val_mean_squared_error: 9.2455
# Epoch 40/40
# 84/84 [==============================] - 20s 236ms/step - loss: 10.2492 - mean_squared_error: 10.2492 - val_loss: 9.2251 - val_mean_squared_error: 9.2251

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model MSE Loss')  # 'model loss'를 'Model MSE Loss'로 변경
plt.ylabel('MSE Loss')  # y축 레이블을 'MSE Loss'로 변경
plt.xlabel('Epoch')  # x축 레이블은 'Epoch' 그대로 유지
plt.legend(['Train', 'Validation'], loc='upper left')  # 범례 그대로 유지
plt.show()

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

predy = model.predict(X_test)

mse = mean_squared_error(y_test, predy)
mae = mean_absolute_error(y_test, predy)
r2 = r2_score(y_test, predy)

print(f'MSE: {mse}')
print(f'MAE: {mae}')
print(f'R^2 Score: {r2}')

plt.scatter(y_test, predy, alpha=0.5)
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='red', linestyle='--')
plt.title('Actual vs Predicted')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
# Out:
# 27/27 [==============================] - 1s 20ms/step
# MSE: 9.343532718060173
# MAE: 2.1953802177374313
# R^2 Score: 0.06026642666673676
# Text(0, 0.5, 'Predicted Values')
