# %%
from sklearn.datasets import load_breast_cancer
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.neighbors import KNeighborsClassifier
import seaborn as sns

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras

# %%
'''url = "http://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data"




columns = ['mpg', 'A' , 'cylinders', 'displacement', 'horsepower', 'weight', 'acceleration', 'model year', 'origin']



df = pd.read_csv(url, delim_whitespace=True, names=columns, na_values='?') 



 
# 결측값 처리 (horsepower 컬럼에 결측값 존재)
df = df.dropna()

    #해당 소스를 활용하여 연비(Mile per gallen)를 예측 

mse를 구하라



1. ML (RF, DT, LR)

2. FCNN

3. 순환데이터로 변환후 CNN



각 단계별 검사후 다음단계 진행'''
# Out:
# 'url = "http://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data"\n\n\n\n\ncolumns = [\'mpg\', \'A\' , \'cylinders\', \'displacement\', \'horsepower\', \'weight\', \'acceleration\', \'model year\', \'origin\']\n\n\n\ndf = pd.read_csv(url, delim_whitespace=True, names=columns, na_values=\'?\') \n\n\n\n \n# 결측값 처리 (horsepower 컬럼에 결측값 존재)\ndf = df.dropna()\n\n    #해당 소스를 활용하여 연비(Mile per gallen)를 예측 \n\nmse를 구하라\n\n\n\n1. ML (RF, DT, LR)\n\n2. FCNN\n\n3. 순환데이터로 변환후 CNN\n\n\n\n각 단계별 검사후 다음단계 진행'

# %%
url = "http://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data"




columns = ['mpg', 'cylinders', 'displacement', 'horsepower', 'weight', 'acceleration', 'model year', 'origin','carname',]



df = pd.read_csv(url, delim_whitespace=True, names=columns, na_values='?')

# %%
df = df.drop('carname',axis=1)

# %%
k = df['mpg']

# %%
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0  3504.0          12.0
# 1    15.0          8         350.0       165.0  3693.0          11.5
# 2    18.0          8         318.0       150.0  3436.0          11.0
# 3    16.0          8         304.0       150.0  3433.0          12.0
# 4    17.0          8         302.0       140.0  3449.0          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0  2790.0          15.6
# 394  44.0          4          97.0        52.0  2130.0          24.6
# 395  32.0          4         135.0        84.0  2295.0          11.6
# 396  28.0          4         120.0        79.0  2625.0          18.6
# 397  31.0          4         119.0        82.0  2720.0          19.4
#
#      model year  origin
# 0            70       1
# 1            70       1
# 2            70       1
# 3            70       1
# 4            70       1
# ..          ...     ...
# 393          82       1
# 394          82       2
# 395          82       1
# 396          82       1
# 397          82       1
#
# [398 rows x 8 columns]

# %%
k
# Out:
# 0      18.0
# 1      15.0
# 2      18.0
# 3      16.0
# 4      17.0
#        ...
# 393    27.0
# 394    44.0
# 395    32.0
# 396    28.0
# 397    31.0
# Name: mpg, Length: 398, dtype: float64

# %%
df['mpg1'] = k

# %%
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0  3504.0          12.0
# 1    15.0          8         350.0       165.0  3693.0          11.5
# 2    18.0          8         318.0       150.0  3436.0          11.0
# 3    16.0          8         304.0       150.0  3433.0          12.0
# 4    17.0          8         302.0       140.0  3449.0          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0  2790.0          15.6
# 394  44.0          4          97.0        52.0  2130.0          24.6
# 395  32.0          4         135.0        84.0  2295.0          11.6
# 396  28.0          4         120.0        79.0  2625.0          18.6
# 397  31.0          4         119.0        82.0  2720.0          19.4
#
#      model year  origin  mpg1
# 0            70       1  18.0
# 1            70       1  15.0
# 2            70       1  18.0
# 3            70       1  16.0
# 4            70       1  17.0
# ..          ...     ...   ...
# 393          82       1  27.0
# 394          82       2  44.0
# 395          82       1  32.0
# 396          82       1  28.0
# 397          82       1  31.0
#
# [398 rows x 9 columns]

# %%
df.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model year      0
# origin          0
# mpg1            0
# dtype: int64

# %%
df = df.dropna()

# %%
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0  3504.0          12.0
# 1    15.0          8         350.0       165.0  3693.0          11.5
# 2    18.0          8         318.0       150.0  3436.0          11.0
# 3    16.0          8         304.0       150.0  3433.0          12.0
# 4    17.0          8         302.0       140.0  3449.0          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0  2790.0          15.6
# 394  44.0          4          97.0        52.0  2130.0          24.6
# 395  32.0          4         135.0        84.0  2295.0          11.6
# 396  28.0          4         120.0        79.0  2625.0          18.6
# 397  31.0          4         119.0        82.0  2720.0          19.4
#
#      model year  origin  mpg1
# 0            70       1  18.0
# 1            70       1  15.0
# 2            70       1  18.0
# 3            70       1  16.0
# 4            70       1  17.0
# ..          ...     ...   ...
# 393          82       1  27.0
# 394          82       2  44.0
# 395          82       1  32.0
# 396          82       1  28.0
# 397          82       1  31.0
#
# [392 rows x 9 columns]

# %%
#1. ML (RF, DT, LR)

# %%
y = df["mpg"]
y.value_counts()
# Out:
# mpg
# 13.0    20
# 14.0    19
# 18.0    17
# 15.0    16
# 26.0    14
#         ..
# 31.9     1
# 16.9     1
# 18.2     1
# 22.3     1
# 44.0     1
# Name: count, Length: 127, dtype: int64

# %%
y
# Out:
# 0      18.0
# 1      15.0
# 2      18.0
# 3      16.0
# 4      17.0
#        ...
# 393    27.0
# 394    44.0
# 395    32.0
# 396    28.0
# 397    31.0
# Name: mpg, Length: 392, dtype: float64

# %%
x = df.drop("mpg" , axis = 1)
x = x.drop("mpg1" , axis = 1)
x
# Out:
#      cylinders  displacement  horsepower  weight  acceleration  model year  \
# 0            8         307.0       130.0  3504.0          12.0          70
# 1            8         350.0       165.0  3693.0          11.5          70
# 2            8         318.0       150.0  3436.0          11.0          70
# 3            8         304.0       150.0  3433.0          12.0          70
# 4            8         302.0       140.0  3449.0          10.5          70
# ..         ...           ...         ...     ...           ...         ...
# 393          4         140.0        86.0  2790.0          15.6          82
# 394          4          97.0        52.0  2130.0          24.6          82
# 395          4         135.0        84.0  2295.0          11.6          82
# 396          4         120.0        79.0  2625.0          18.6          82
# 397          4         119.0        82.0  2720.0          19.4          82
#
#      origin
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
# ..      ...
# 393       1
# 394       2
# 395       1
# 396       1
# 397       1
#
# [392 rows x 7 columns]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test=train_test_split(x,
                                                  y,
                                                  test_size=0.2,
                                                  shuffle=True,
                                                  random_state=12)
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (313, 7) (313,)
# (79, 7) (79,)

# %%
#1. ML (RF, DT, LR)

# %%
#RandomForest
from sklearn.ensemble import RandomForestRegressor

model = RandomForestRegressor()
model.fit(X_train, y_train)

from sklearn.metrics import mean_squared_error

ry_preds = model.predict(X_test)
print('평균제곱근오차', mean_squared_error(ry_preds, y_test))
# Out:
# 평균제곱근오차 11.093472075949364

# %%
#DT
from sklearn.tree import DecisionTreeRegressor

model = DecisionTreeRegressor()
model.fit(X_train, y_train)

from sklearn.metrics import mean_squared_error

dy_preds = model.predict(X_test)
print('평균제곱근오차', mean_squared_error(dy_preds, y_test))
# Out:
# 평균제곱근오차 15.523670886075951

# %%
# LR
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

model = LinearRegression()
model.fit(X_train, y_train)
ly_preds = model.predict(X_test)

print('평균제곱근오차', mean_squared_error(ly_preds, y_test))
# Out:
# 평균제곱근오차 14.153697740101125

# %%
X_train.shape, y_train.shape, X_test.shape, y_test.shape,
# Out:
# ((313, 7), (313,), (79, 7), (79,))

# %%
# 2. FCNN

# %%
#Defining the model 

from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD, Adam

model = Sequential()
model.add(Dense(10, input_shape=(7,), activation='tanh'))  
model.add(Dense(50, activation='tanh'))
model.add(Dense(50, activation='tanh'))
model.add(Dense(1,))

model.compile(optimizer = 'adam', loss = 'mse', metrics = ['mse'])

model.summary()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_34 (Dense)            (None, 10)                80
#
#  dense_35 (Dense)            (None, 50)                550
#
#  dense_36 (Dense)            (None, 50)                2550
#
#  dense_37 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 3,231
# Trainable params: 3,231
# Non-trainable params: 0
# _________________________________________________________________

# %%
N_EPOCHS = 100

history=model.fit(x=X_train, y=y_train, epochs=N_EPOCHS, batch_size=32,validation_data= (X_train,y_train))
y_pred = model.predict(X_test)
# Out:
# Epoch 1/100
#  1/10 [==>...........................] - ETA: 2s - loss: 576.3446 - mse: 576.3446
# 2024-10-24 11:03:01.125760: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 10/10 [==============================] - 1s 38ms/step - loss: 526.6133 - mse: 526.6133 - val_loss: 469.8169 - val_mse: 469.8169
# Epoch 2/100
# 10/10 [==============================] - ETA: 0s - loss: 431.4691 - mse: 431.4691
# 2024-10-24 11:03:01.504269: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 10/10 [==============================] - 0s 10ms/step - loss: 431.4691 - mse: 431.4691 - val_loss: 387.8414 - val_mse: 387.8414
# Epoch 3/100
# 10/10 [==============================] - 0s 9ms/step - loss: 359.1658 - mse: 359.1658 - val_loss: 326.1674 - val_mse: 326.1674
# Epoch 4/100
# 10/10 [==============================] - 0s 9ms/step - loss: 305.1953 - mse: 305.1953 - val_loss: 281.3863 - val_mse: 281.3863
# Epoch 5/100
# 10/10 [==============================] - 0s 9ms/step - loss: 266.6564 - mse: 266.6564 - val_loss: 249.4120 - val_mse: 249.4120
# Epoch 6/100
# 10/10 [==============================] - 0s 10ms/step - loss: 238.5384 - mse: 238.5384 - val_loss: 225.7851 - val_mse: 225.7851
# Epoch 7/100
# 10/10 [==============================] - 0s 9ms/step - loss: 217.1995 - mse: 217.1995 - val_loss: 207.1000 - val_mse: 207.1000
# Epoch 8/100
# 10/10 [==============================] - 0s 9ms/step - loss: 199.9721 - mse: 199.9721 - val_loss: 191.4388 - val_mse: 191.4388
100
# 10/10 [==============================] - 0s 8ms/step - loss: 58.7084 - mse: 58.7084 - val_loss: 58.6632 - val_mse: 58.6632
# Epoch 53/100
# 10/10 [==============================] - 0s 8ms/step - loss: 58.6690 - mse: 58.6690 - val_loss: 58.5943 - val_mse: 58.5943
# Epoch 54/100
# 10/10 [==============================] - 0s 8ms/step - loss: 58.5853 - mse: 58.5853 - val_loss: 58.5553 - val_mse: 58.5553
# Epoch 55/100
# 10/10 [==============================] - 0s 8ms/step - loss: 58.5476 - mse: 58.5476 - val_loss: 58.5203 - val_mse: 58.5203
# Epoch 56/100
# 10/10 [==============================] - 0s 8ms/step - loss: 58.5091 - mse: 58.5091 - val_loss: 58.4983 - val_mse: 58.4983
# Epoch 57/100
# 10/10 [==============================] - 0s 8ms/step - loss: 58.4989 - mse: 58.4989 - val_loss: 58.4654 - val_mse: 58.4654
# Epoch 58/100
# 10/10 [==============================] - 0s 8ms/step - loss: 58.4561 - mse: 58.4561 - val_loss: 58.4508 - val_mse: 58.4508
# Epoch 59/100
# 10/10 [==============================] - 0s 8ms/step - loss: 58.4414 - mse: 58.4414 - val_loss: 58.4276 - val_mse: 58.4276
# Epoch 60/100
# 10/10 [==============================] - 0s 8ms/step - loss: 58.4203 - mse: 58.4203 - val_loss: 58.4154 - val_mse: 58.4154
# Epoch 61/100
# 10/10 [==============================] - 0s 8ms/step - loss: 58.4087 - mse: 58.4087 - val_loss: 58.3981 - val_mse: 58.3981
# Epoch 62/100
# 10/10 [==============================] - 0s 8ms/step - loss: 58.3919 - mse: 58.3919 - val_loss: 58.3869 - val_mse: 58.3869
# Epoch 63/100
# 10/10 [==============================] - 0s 8ms/step - loss: 58.3803 - mse: 58.3803 - val_loss: 58.3776 - val_mse: 58.3776
# Epoch 64/100
# 10/10 [==============================] - 0s 8ms/step - loss: 58.3755 - mse: 58.3755 - val_loss: 58.3733 - val_mse: 58.3733
# Epoch 65/100
# 10/10 [==============================] - 0s 8ms/step - loss: 58.3708 - mse: 58.3708 - val_loss: 58.3611 - val_mse: 58.3611
# Epoch 66/100
# 10/10 [==============================] - 0s 8ms/step - loss: 58.3655 - mse: 58.3655 - val_loss: 58.3544 - val_mse: 58.3544
# Epoch 67/100
# 10/10 [==============================] - 0s 8ms/step - loss: 58.3546 - mse: 58.3546 - val_loss: 58.3528 - val_mse: 58.3528
# Epoch 68/100
# 10/10 [==============================] - 0s 9ms/step - loss: 58.3542 - mse: 58.3542 - val_loss: 58.3490 - val_mse: 58.3490
# Epoch 69/100
# 10/10 [==============================] - 0s 9ms/step - loss: 58.3576 - mse: 58.3576 - val_loss: 58.3496 - val_mse: 58.3496
# Epoch 70/100
# 10/10 [==============================] - 0s 9ms/step - loss: 58.3524 - mse: 58.3524 - val_loss: 58.3495 - val_mse: 58.3495
# Epoch 71/100
# 10/10 [==============================] - 0s 9ms/step - loss: 58.3547 - mse: 58.3547 - val_loss: 58.3443 - val_mse: 58.3443
# Epoch 72/100
# 10/10 [==============================] - 0s 9ms/step - loss: 58.3547 - mse: 58.3547 - val_loss: 58.3415 - val_mse: 58.3415
# Epoch 73/100
# 10/10 [==============================] - 0s 9ms/step - loss: 58.3475 - mse: 58.3475 - val_loss: 58.3421 - val_mse: 58.3421
# Epoch 74/100
# 10/10 [==============================] - 0s 8ms/step - loss: 58.3488 - mse: 58.3488 - val_loss: 58.3407 - val_mse: 58.3407
# Epoch 75/100
# 10/10 [==============================] - 0s 9ms/step - loss: 58.3479 - mse: 58.3479 - val_loss: 58.3414 - val_mse: 58.3414
# Epoch 76/100
# 10/10 [==============================] - 0s 8ms/step - loss: 58.3453 - mse: 58.3453 - val_loss: 58.3403 - val_mse: 58.3403
# Epoch 77/100
# 10/10 [==============================] - 0s 8ms/step - loss: 58.3418 - mse: 58.3418 - val_loss: 58.3401 - val_mse: 58.3401
# Epoch 78/100
# 10/10 [==============================] - 0s 8ms/step - loss: 58.3438 - mse: 58.3438 - val_loss: 58.3398 - val_mse: 58.3398
# Epoch 79/100
# 10/10 [==============================] - 0s 8ms/step - loss: 58.3411 - mse: 58.3411 - val_loss: 58.3392 - val_mse: 58.3392
# Epoch 80/100
# 10/10 [==============================] - 0s 8ms/step - loss: 58.3404 - mse: 58.3404 - val_loss: 58.3390 - val_mse: 58.3390
# Epoch 81/100
# 10/10 [==============================] - 0s 9ms/step - loss: 58.3421 - mse: 58.3421 - val_loss: 58.3388 - val_mse: 58.3388
# Epoch 82/100
# 10/10 [==============================] - 0s 9ms/step - loss: 58.3399 - mse: 58.3399 - val_loss: 58.3389 - val_mse: 58.3389
# Epoch 83/100
# 10/10 [==============================] - 0s 9ms/step - loss: 58.3403 - mse: 58.3403 - val_loss: 58.3386 - val_mse: 58.3386
# Epoch 84/100
# 10/10 [==============================] - 0s 9ms/step - loss: 58.3500 - mse: 58.3500 - val_loss: 58.3384 - val_mse: 58.3384
# Epoch 85/100
# 10/10 [==============================] - 0s 9ms/step - loss: 58.3455 - mse: 58.3455 - val_loss: 58.3384 - val_mse: 58.3384
# Epoch 86/100
# 10/10 [==============================] - 0s 8ms/step - loss: 58.3415 - mse: 58.3415 - val_loss: 58.3385 - val_mse: 58.3385
# Epoch 87/100
# 10/10 [==============================] - 0s 8ms/step - loss: 58.3463 - mse: 58.3463 - val_loss: 58.3385 - val_mse: 58.3385
# Epoch 88/100
# 10/10 [==============================] - 0s 8ms/step - loss: 58.3404 - mse: 58.3404 - val_loss: 58.3384 - val_mse: 58.3384
# Epoch 89/100
# 10/10 [==============================] - 0s 8ms/step - loss: 58.3461 - mse: 58.3461 - val_loss: 58.3385 - val_mse: 58.3385
# Epoch 90/100
# 10/10 [==============================] - 0s 8ms/step - loss: 58.3464 - mse: 58.3464 - val_loss: 58.3387 - val_mse: 58.3387
# Epoch 91/100
# 10/10 [==============================] - 0s 8ms/step - loss: 58.3437 - mse: 58.3437 - val_loss: 58.3387 - val_mse: 58.3387
# Epoch 92/100
# 10/10 [==============================] - 0s 8ms/step - loss: 58.3462 - mse: 58.3462 - val_loss: 58.3388 - val_mse: 58.3388
# Epoch 93/100
# 10/10 [==============================] - 0s 9ms/step - loss: 58.3412 - mse: 58.3412 - val_loss: 58.3386 - val_mse: 58.3386
# Epoch 94/100
# 10/10 [==============================] - 0s 11ms/step - loss: 58.3393 - mse: 58.3393 - val_loss: 58.3386 - val_mse: 58.3386
# Epoch 95/100
# 10/10 [==============================] - 0s 8ms/step - loss: 58.3401 - mse: 58.3401 - val_loss: 58.3385 - val_mse: 58.3385
# Epoch 96/100
# 10/10 [==============================] - 0s 8ms/step - loss: 58.3394 - mse: 58.3394 - val_loss: 58.3384 - val_mse: 58.3384
# Epoch 97/100
# 10/10 [==============================] - 0s 8ms/step - loss: 58.3444 - mse: 58.3444 - val_loss: 58.3386 - val_mse: 58.3386
# Epoch 98/100
# 10/10 [==============================] - 0s 8ms/step - loss: 58.3441 - mse: 58.3441 - val_loss: 58.3385 - val_mse: 58.3385
# Epoch 99/100
# 10/10 [==============================] - 0s 9ms/step - loss: 58.3428 - mse: 58.3428 - val_loss: 58.3385 - val_mse: 58.3385
# Epoch 100/100
# 10/10 [==============================] - 0s 8ms/step - loss: 58.3454 - mse: 58.3454 - val_loss: 58.3385 - val_mse: 58.3385
# 3/3 [==============================] - 0s 12ms/step
# 2024-10-24 11:03:10.032594: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model MSE Loss')  # 'model loss'를 'Model MSE Loss'로 변경
plt.ylabel('MSE Loss')  # y축 레이블을 'MSE Loss'로 변경
plt.xlabel('Epoch')  # x축 레이블은 'Epoch' 그대로 유지
plt.legend(['Train', 'Validation'], loc='upper left')  # 범례 그대로 유지
plt.show()

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

predy = model.predict(X_test)

mse = mean_squared_error(y_test, predy)
mae = mean_absolute_error(y_test, predy)
r2 = r2_score(y_test, predy)

print(f'MSE: {mse}')
print(f'MAE: {mae}')
print(f'R^2 Score: {r2}')

plt.scatter(y_test, predy, alpha=0.5)
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='red', linestyle='--')
plt.title('Actual vs Predicted')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
# Out:
# 3/3 [==============================] - 0s 3ms/step
# MSE: 70.97481652060807
# MAE: 6.910368960416769
# R^2 Score: -0.043577285341730665
# Text(0, 0.5, 'Predicted Values')

# %%
#3. 순환데이터로 변환후 CNN

# %%
# split_sequence 함수
def split_sequence(df, n_steps):
    X, y = [], []
    for i in range(len(df) - n_steps):
        seq_x = df.iloc[i:i+n_steps, :-1].values  
        seq_y = df.iloc[i+n_steps, -1]  
        X.append(seq_x)
        y.append(seq_y)
    return np.array(X), np.array(y)

# %%
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0  3504.0          12.0
# 1    15.0          8         350.0       165.0  3693.0          11.5
# 2    18.0          8         318.0       150.0  3436.0          11.0
# 3    16.0          8         304.0       150.0  3433.0          12.0
# 4    17.0          8         302.0       140.0  3449.0          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0  2790.0          15.6
# 394  44.0          4          97.0        52.0  2130.0          24.6
# 395  32.0          4         135.0        84.0  2295.0          11.6
# 396  28.0          4         120.0        79.0  2625.0          18.6
# 397  31.0          4         119.0        82.0  2720.0          19.4
#
#      model year  origin  mpg1
# 0            70       1  18.0
# 1            70       1  15.0
# 2            70       1  18.0
# 3            70       1  16.0
# 4            70       1  17.0
# ..          ...     ...   ...
# 393          82       1  27.0
# 394          82       2  44.0
# 395          82       1  32.0
# 396          82       1  28.0
# 397          82       1  31.0
#
# [392 rows x 9 columns]

# %%
df = df.drop('mpg',axis=1)

# %%
df
# Out:
#      cylinders  displacement  horsepower  weight  acceleration  model year  \
# 0            8         307.0       130.0  3504.0          12.0          70
# 1            8         350.0       165.0  3693.0          11.5          70
# 2            8         318.0       150.0  3436.0          11.0          70
# 3            8         304.0       150.0  3433.0          12.0          70
# 4            8         302.0       140.0  3449.0          10.5          70
# ..         ...           ...         ...     ...           ...         ...
# 393          4         140.0        86.0  2790.0          15.6          82
# 394          4          97.0        52.0  2130.0          24.6          82
# 395          4         135.0        84.0  2295.0          11.6          82
# 396          4         120.0        79.0  2625.0          18.6          82
# 397          4         119.0        82.0  2720.0          19.4          82
#
#      origin  mpg1
# 0         1  18.0
# 1         1  15.0
# 2         1  18.0
# 3         1  16.0
# 4         1  17.0
# ..      ...   ...
# 393       1  27.0
# 394       2  44.0
# 395       1  32.0
# 396       1  28.0
# 397       1  31.0
#
# [392 rows x 8 columns]

# %%
n_steps = 7

X, y = split_sequence(df, n_steps)
print("입력 데이터 (X):", X)
print("출력 데이터 (y):", y)
# Out:
# 입력 데이터 (X): [[[  8.  307.  130.  ...  12.   70.    1. ]
#   [  8.  350.  165.  ...  11.5  70.    1. ]
#   [  8.  318.  150.  ...  11.   70.    1. ]
#   ...
#   [  8.  302.  140.  ...  10.5  70.    1. ]
#   [  8.  429.  198.  ...  10.   70.    1. ]
#   [  8.  454.  220.  ...   9.   70.    1. ]]
#
#  [[  8.  350.  165.  ...  11.5  70.    1. ]
#   [  8.  318.  150.  ...  11.   70.    1. ]
#   [  8.  304.  150.  ...  12.   70.    1. ]
#   ...
#   [  8.  429.  198.  ...  10.   70.    1. ]
#   [  8.  454.  220.  ...   9.   70.    1. ]
#   [  8.  440.  215.  ...   8.5  70.    1. ]]
#
#  [[  8.  318.  150.  ...  11.   70.    1. ]
#   [  8.  304.  150.  ...  12.   70.    1. ]
#   [  8.  302.  140.  ...  10.5  70.    1. ]
#   ...
#   [  8.  454.  220.  ...   9.   70.    1. ]
#   [  8.  440.  215.  ...   8.5  70.    1. ]
#   [  8.  455.  225.  ...  10.   70.    1. ]]
#
#  ...
#
#  [[  4.  156.   92.  ...  14.5  82.    1. ]
#   [  6.  232.  112.  ...  14.7  82.    1. ]
#   [  4.  144.   96.  ...  13.9  82.    3. ]
#   ...
#   [  4.  151.   90.  ...  17.3  82.    1. ]
#   [  4.  140.   86.  ...  15.6  82.    1. ]
#   [  4.   97.   52.  ...  24.6  82.    2. ]]
#
#  [[  6.  232.  112.  ...  14.7  82.    1. ]
#   [  4.  144.   96.  ...  13.9  82.    3. ]
#   [  4.  135.   84.  ...  13.   82.    1. ]
#   ...
#   [  4.  140.   86.  ...  15.6  82.    1. ]


# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=32)

X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=32)

X_train.shape, X_test.shape, y_train.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((246, 7, 7), (77, 7, 7), (246,), (77,), (62, 7, 7), (62,))

# %%
n_timesteps, n_features = X_train.shape[1], X_train.shape[2]

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, Dense, Dropout, Flatten, Reshape, LSTM, Conv1D, MaxPooling1D, Bidirectional, ConvLSTM1D
model = Sequential()
model.add(Conv1D(filters=16, kernel_size=3, activation='relu', input_shape=(n_timesteps, n_features)))
model.add(Conv1D(filters=32, kernel_size=3, activation='relu'))
model.add(Conv1D(filters=32, kernel_size=3, activation='relu'))
model.add(Flatten())
model.add(Dense(16, activation='relu'))
model.add(Dense(1, activation='linear'))  # 출력 레이어, 회귀이므로 'linear' 사용
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_squared_error'])  # 회귀에서는 MSE 사용
model.summary()
# Out:
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_6 (Conv1D)           (None, 5, 16)             352
#
#  conv1d_7 (Conv1D)           (None, 3, 32)             1568
#
#  conv1d_8 (Conv1D)           (None, 1, 32)             3104
#
#  flatten_2 (Flatten)         (None, 32)                0
#
#  dense_38 (Dense)            (None, 16)                528
#
#  dense_39 (Dense)            (None, 1)                 17
#
# =================================================================
# Total params: 5,569
# Trainable params: 5,569
# Non-trainable params: 0
# _________________________________________________________________

# %%
batch_size = 16

train_epochs = 100
history = model.fit(X_train, y_train, epochs=train_epochs, batch_size=batch_size, validation_data=(X_val, y_val), verbose=True, shuffle=True)
# Out:
# Epoch 1/100
# 2024-10-24 11:03:41.643211: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 16/16 [==============================] - 1s 28ms/step - loss: 1510.7289 - mean_squared_error: 1510.7289 - val_loss: 277.4278 - val_mean_squared_error: 277.4278
# Epoch 2/100
#  1/16 [>.............................] - ETA: 0s - loss: 247.5403 - mean_squared_error: 247.5403
# 2024-10-24 11:03:42.140443: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 16/16 [==============================] - 0s 8ms/step - loss: 216.3093 - mean_squared_error: 216.3093 - val_loss: 165.8214 - val_mean_squared_error: 165.8214
# Epoch 3/100
# 16/16 [==============================] - 0s 7ms/step - loss: 140.9953 - mean_squared_error: 140.9953 - val_loss: 124.2971 - val_mean_squared_error: 124.2971
# Epoch 4/100
# 16/16 [==============================] - 0s 7ms/step - loss: 140.7130 - mean_squared_error: 140.7130 - val_loss: 110.2138 - val_mean_squared_error: 110.2138
# Epoch 5/100
# 16/16 [==============================] - 0s 7ms/step - loss: 117.5425 - mean_squared_error: 117.5425 - val_loss: 105.8637 - val_mean_squared_error: 105.8637
# Epoch 6/100
# 16/16 [==============================] - 0s 7ms/step - loss: 110.5788 - mean_squared_error: 110.5788 - val_loss: 112.6027 - val_mean_squared_error: 112.6027
# Epoch 7/100
# 16/16 [==============================] - 0s 7ms/step - loss: 102.8466 - mean_squared_error: 102.8466 - val_loss: 99.7652 - val_mean_squared_error: 99.7652
# Epoch 8/100
# 16/16 [==============================] - 0s 7ms/step - loss: 99.7634 - mean_squared_error: 99.7634 - val_loss: 110.6209 - val_mean_squared_error: 110.6209
# Epoch 9/100
# 16/16 [==============================] - 0s 7ms/step - loss: 98.2512 - mean_squared_error: 98.2512 - val_loss: 102.0303 - val_mean_squared_error: 102.0303
# Epoch 10/100
# 16/16 [==============================] - 0s 7ms/step - loss: 92.2366 - mean_squared_error: 92.2366 - val_loss: 129.5532 - val_mean_squared_error: 129.5532
# Epoch 11/100
# 16/16 [==============================] - 0s 7ms/step - loss: 94.6566 - mean_squared_error: 94.6566 - val_loss: 87.2951 - val_mean_squared_error: 87.2951
# Epoch 12/100
# 16/16 [==============================] - 0s 7ms/step - loss: 34.2627 - mean_squared_error: 34.2627 - val_loss: 42.1333 - val_mean_squared_error: 42.1333
# Epoch 88/100
# 16/16 [==============================] - 0s 7ms/step - loss: 31.9497 - mean_squared_error: 31.9497 - val_loss: 40.7932 - val_mean_squared_error: 40.7932
# Epoch 89/100
# 16/16 [==============================] - 0s 7ms/step - loss: 36.1197 - mean_squared_error: 36.1197 - val_loss: 50.0191 - val_mean_squared_error: 50.0191
# Epoch 90/100
# 16/16 [==============================] - 0s 6ms/step - loss: 37.5151 - mean_squared_error: 37.5151 - val_loss: 39.9048 - val_mean_squared_error: 39.9048
# Epoch 91/100
# 16/16 [==============================] - 0s 6ms/step - loss: 38.1169 - mean_squared_error: 38.1169 - val_loss: 53.1651 - val_mean_squared_error: 53.1651
# Epoch 92/100
# 16/16 [==============================] - 0s 7ms/step - loss: 40.1056 - mean_squared_error: 40.1056 - val_loss: 56.0265 - val_mean_squared_error: 56.0265
# Epoch 93/100
# 16/16 [==============================] - 0s 7ms/step - loss: 34.9105 - mean_squared_error: 34.9105 - val_loss: 44.8098 - val_mean_squared_error: 44.8098
# Epoch 94/100
# 16/16 [==============================] - 0s 7ms/step - loss: 30.5653 - mean_squared_error: 30.5653 - val_loss: 35.1219 - val_mean_squared_error: 35.1219
# Epoch 95/100
# 16/16 [==============================] - 0s 7ms/step - loss: 29.8005 - mean_squared_error: 29.8005 - val_loss: 57.5908 - val_mean_squared_error: 57.5908
# Epoch 96/100
# 16/16 [==============================] - 0s 7ms/step - loss: 30.5284 - mean_squared_error: 30.5284 - val_loss: 45.7898 - val_mean_squared_error: 45.7898
# Epoch 97/100
# 16/16 [==============================] - 0s 7ms/step - loss: 31.3551 - mean_squared_error: 31.3551 - val_loss: 50.4696 - val_mean_squared_error: 50.4696
# Epoch 98/100
# 16/16 [==============================] - 0s 7ms/step - loss: 34.1103 - mean_squared_error: 34.1103 - val_loss: 38.7638 - val_mean_squared_error: 38.7638
# Epoch 99/100
# 16/16 [==============================] - 0s 7ms/step - loss: 27.2727 - mean_squared_error: 27.2727 - val_loss: 37.0210 - val_mean_squared_error: 37.0210
# Epoch 100/100
# 16/16 [==============================] - 0s 7ms/step - loss: 28.4816 - mean_squared_error: 28.4816 - val_loss: 40.3725 - val_mean_squared_error: 40.3725

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model MSE Loss')  # 'model loss'를 'Model MSE Loss'로 변경
plt.ylabel('MSE Loss')  # y축 레이블을 'MSE Loss'로 변경
plt.xlabel('Epoch')  # x축 레이블은 'Epoch' 그대로 유지
plt.legend(['Train', 'Validation'], loc='upper left')  # 범례 그대로 유지
plt.show()

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

predy = model.predict(X_test)

mse = mean_squared_error(y_test, predy)
mae = mean_absolute_error(y_test, predy)
r2 = r2_score(y_test, predy)

print(f'MSE: {mse}')
print(f'MAE: {mae}')
print(f'R^2 Score: {r2}')

plt.scatter(y_test, predy, alpha=0.5)
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='red', linestyle='--')
plt.title('Actual vs Predicted')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
# Out:
# 3/3 [==============================] - 0s 22ms/step
# MSE: 43.279440504891035
# MAE: 5.170585986546108
# R^2 Score: 0.3114598253401276
# 2024-10-24 11:03:54.557579: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# Text(0, 0.5, 'Predicted Values')
