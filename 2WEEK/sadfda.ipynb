# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/Users/ohheungchan/workspace/AI_Study/abalone.csv")
df
# Out:
#         id Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  \
# 0        0   M   0.455     0.365   0.095        0.5140          0.2245
# 1        1   M   0.350     0.265   0.090        0.2255          0.0995
# 2        2   F   0.530     0.420   0.135        0.6770          0.2565
# 3        3   M   0.440     0.365   0.125        0.5160          0.2155
# 4        4   I   0.330     0.255   0.080        0.2050          0.0895
# ...    ...  ..     ...       ...     ...           ...             ...
# 4172  4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173  4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174  4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175  4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176  4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera_weight  Shell_weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# 3             0.1140        0.1550     10
# 4             0.0395        0.0550      7
# ...              ...           ...    ...
# 4172          0.2390        0.2490     11
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4175          0.2610        0.2960     10
# 4176          0.3765        0.4950     12
#
# [4177 rows x 10 columns]

# %% [markdown]
# ## 결측치 확인

# %%
df.isnull().sum()
# Out:
# id                0
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole_weight      0
# Shucked_weight    0
# Viscera_weight    0
# Shell_weight      0
# Rings             0
# dtype: int64

# %% [markdown]
# ## 이상치 확인

# %%
# 수치형 데이터 열만 선택
numeric_columns = df.select_dtypes(include=['float64', 'int64']).columns

# 박스플롯을 그리기 위한 설정
plt.figure(figsize=(15, 10))

# 각 변수에 대해 개별 박스플롯을 그립니다.
for i, column in enumerate(numeric_columns, 1):
    plt.subplot(3, 3, i)  # 3x3 grid로 subplot을 설정
    df.boxplot(column)
    plt.title(f'Boxplot of {column}')

# 레이아웃을 자동으로 조정하여 겹치지 않게 함
plt.tight_layout()

# 플롯을 출력
plt.show()

# %% [markdown]
# ### 컬럼 설명
#
# 1. **Sex**: 전복의 성별 (M: 수컷, F: 암컷, I: 새끼)
# 2. **Length**: 전복의 최대 길이 (밀리미터 단위)
# 3. **Diameter**: 전복의 지름, 길이에 수직인 측정치 (밀리미터 단위)
# 4. **Height**: 전복의 높이, 껍질 속 고기 포함 (밀리미터 단위)
# 5. **Whole weight**: 전복 전체의 무게 (그램 단위)
# 6. **Shucked weight**: 전복 고기의 무게 (그램 단위)
# 7. **Viscera weight**: 전복의 내장 무게, 출혈 후 측정 (그램 단위)
# 8. **Shell weight**: 건조 후 전복 껍질의 무게 (그램 단위)
# 9. **Rings**: 전복의 고리 수, 나이 추정의 기준 (+1.5년)

# %%
df.info
# Out:
# <bound method DataFrame.info of         id Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  \
# 0        0   M   0.455     0.365   0.095        0.5140          0.2245
# 1        1   M   0.350     0.265   0.090        0.2255          0.0995
# 2        2   F   0.530     0.420   0.135        0.6770          0.2565
# 3        3   M   0.440     0.365   0.125        0.5160          0.2155
# 4        4   I   0.330     0.255   0.080        0.2050          0.0895
# ...    ...  ..     ...       ...     ...           ...             ...
# 4172  4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173  4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174  4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175  4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176  4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera_weight  Shell_weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# 3             0.1140        0.1550     10
# 4             0.0395        0.0550      7
# ...              ...           ...    ...
# 4172          0.2390        0.2490     11
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4175          0.2610        0.2960     10
# 4176          0.3765        0.4950     12
#
# [4177 rows x 10 columns]>

# %%
df.columns
# Out:
# Index(['id', 'Sex', 'Length', 'Diameter', 'Height', 'Whole_weight',
#        'Shucked_weight', 'Viscera_weight', 'Shell_weight', 'Rings'],
#       dtype='object')

# %% [markdown]
# ### 인코딩 (문자->수치)

# %%
# 'Sex'컬럼의 F/M을 수치화
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()
df['Sex'] = label.fit_transform(df['Sex'])

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# 카운트플롯 그리기
plt.figure(figsize=(10, 6))
sns.countplot(x='Rings', data=df, palette='Set3')
plt.title('Count of Each Rings Value', fontsize=16)
plt.xlabel('Rings', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.xticks(rotation=45)  # x축 값이 겹치지 않도록 회전
plt.show()
# Out:
# /var/folders/9x/8whwzmnj6z5bjc7_h1txd9_r0000gn/T/ipykernel_56677/2749004283.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Rings', data=df, palette='Set3')

# %%
df_corr=df.corr()

#히트맵
plt.figure(figsize=(10,10))
sns.set(font_scale=0.8)
sns.heatmap(df_corr, annot=True, cbar=False)
plt.show()

# %%
y = df["Rings"]
y
# Out:
# 0       15
# 1        7
# 2        9
# 3       10
# 4        7
#         ..
# 4172    11
# 4173    10
# 4174     9
# 4175    10
# 4176    12
# Name: Rings, Length: 4177, dtype: int64

# %%
y.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0       15
# 1        7
# 2        9
# 3       10
# 4        7
#         ..
# 4172    11
# 4173    10
# 4174     9
# 4175    10
# 4176    12
# Name: Rings, Length: 4177, dtype: int64>

# %%
x = df.drop("Rings" , axis = 1)
x
# Out:
#         id  Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  \
# 0        0    2   0.455     0.365   0.095        0.5140          0.2245
# 1        1    2   0.350     0.265   0.090        0.2255          0.0995
# 2        2    0   0.530     0.420   0.135        0.6770          0.2565
# 3        3    2   0.440     0.365   0.125        0.5160          0.2155
# 4        4    1   0.330     0.255   0.080        0.2050          0.0895
# ...    ...  ...     ...       ...     ...           ...             ...
# 4172  4172    0   0.565     0.450   0.165        0.8870          0.3700
# 4173  4173    2   0.590     0.440   0.135        0.9660          0.4390
# 4174  4174    2   0.600     0.475   0.205        1.1760          0.5255
# 4175  4175    0   0.625     0.485   0.150        1.0945          0.5310
# 4176  4176    2   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera_weight  Shell_weight
# 0             0.1010        0.1500
# 1             0.0485        0.0700
# 2             0.1415        0.2100
# 3             0.1140        0.1550
# 4             0.0395        0.0550
# ...              ...           ...
# 4172          0.2390        0.2490
# 4173          0.2145        0.2605
# 4174          0.2875        0.3080
# 4175          0.2610        0.2960
# 4176          0.3765        0.4950
#
# [4177 rows x 9 columns]

# %%
print(x.shape)
print(y.shape)
# Out:
# (4177, 9)
# (4177,)

# %%
df.hist(bins=50, figsize=(12, 8))
# Out:
# array([[<Axes: title={'center': 'id'}>, <Axes: title={'center': 'Sex'}>,
#         <Axes: title={'center': 'Length'}>],
#        [<Axes: title={'center': 'Diameter'}>,
#         <Axes: title={'center': 'Height'}>,
#         <Axes: title={'center': 'Whole_weight'}>],
#        [<Axes: title={'center': 'Shucked_weight'}>,
#         <Axes: title={'center': 'Viscera_weight'}>,
#         <Axes: title={'center': 'Shell_weight'}>],
#        [<Axes: title={'center': 'Rings'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
# split_sequence 함수
def split_sequence(df, n_steps):
    X, y = [], []
    for i in range(len(df) - n_steps):
        seq_x = df.iloc[i:i+n_steps, :-1].values  # 마지막 열(Rings)을 제외한 특징들
        seq_y = df.iloc[i+n_steps, -1]  # Rings (예측할 값)
        X.append(seq_x)
        y.append(seq_y)
    return np.array(X), np.array(y)

# %%
n_steps = 7

X, y = split_sequence(df, n_steps)
print("입력 데이터 (X):", X)
print("출력 데이터 (y):", y)
# Out:
# 입력 데이터 (X): [[[0.000e+00 2.000e+00 4.550e-01 ... 2.245e-01 1.010e-01 1.500e-01]
#   [1.000e+00 2.000e+00 3.500e-01 ... 9.950e-02 4.850e-02 7.000e-02]
#   [2.000e+00 0.000e+00 5.300e-01 ... 2.565e-01 1.415e-01 2.100e-01]
#   ...
#   [4.000e+00 1.000e+00 3.300e-01 ... 8.950e-02 3.950e-02 5.500e-02]
#   [5.000e+00 1.000e+00 4.250e-01 ... 1.410e-01 7.750e-02 1.200e-01]
#   [6.000e+00 0.000e+00 5.300e-01 ... 2.370e-01 1.415e-01 3.300e-01]]
#
#  [[1.000e+00 2.000e+00 3.500e-01 ... 9.950e-02 4.850e-02 7.000e-02]
#   [2.000e+00 0.000e+00 5.300e-01 ... 2.565e-01 1.415e-01 2.100e-01]
#   [3.000e+00 2.000e+00 4.400e-01 ... 2.155e-01 1.140e-01 1.550e-01]
#   ...
#   [5.000e+00 1.000e+00 4.250e-01 ... 1.410e-01 7.750e-02 1.200e-01]
#   [6.000e+00 0.000e+00 5.300e-01 ... 2.370e-01 1.415e-01 3.300e-01]
#   [7.000e+00 0.000e+00 5.450e-01 ... 2.940e-01 1.495e-01 2.600e-01]]
100
# 167/167 [==============================] - 1s 8ms/step - loss: 9.0684 - mean_squared_error: 9.0684 - val_loss: 8.6857 - val_mean_squared_error: 8.6857
# Epoch 85/100
# 167/167 [==============================] - 1s 9ms/step - loss: 9.1031 - mean_squared_error: 9.1031 - val_loss: 8.8903 - val_mean_squared_error: 8.8903
# Epoch 86/100
# 167/167 [==============================] - 1s 8ms/step - loss: 8.8866 - mean_squared_error: 8.8866 - val_loss: 10.2657 - val_mean_squared_error: 10.2657
# Epoch 87/100
# 167/167 [==============================] - 1s 9ms/step - loss: 9.2326 - mean_squared_error: 9.2326 - val_loss: 9.1507 - val_mean_squared_error: 9.1507
# Epoch 88/100
# 167/167 [==============================] - 1s 8ms/step - loss: 9.1756 - mean_squared_error: 9.1756 - val_loss: 11.1276 - val_mean_squared_error: 11.1276
# Epoch 89/100
# 167/167 [==============================] - 1s 9ms/step - loss: 9.1576 - mean_squared_error: 9.1576 - val_loss: 8.7643 - val_mean_squared_error: 8.7643
# Epoch 90/100
# 167/167 [==============================] - 1s 9ms/step - loss: 9.1898 - mean_squared_error: 9.1898 - val_loss: 8.8819 - val_mean_squared_error: 8.8819
# Epoch 91/100
# 167/167 [==============================] - 1s 8ms/step - loss: 9.1372 - mean_squared_error: 9.1372 - val_loss: 9.3216 - val_mean_squared_error: 9.3216
# Epoch 92/100
# 167/167 [==============================] - 1s 9ms/step - loss: 8.8715 - mean_squared_error: 8.8715 - val_loss: 8.7648 - val_mean_squared_error: 8.7648
# Epoch 93/100
# 167/167 [==============================] - 1s 8ms/step - loss: 9.2932 - mean_squared_error: 9.2932 - val_loss: 9.5273 - val_mean_squared_error: 9.5273
# Epoch 94/100
# 167/167 [==============================] - 1s 9ms/step - loss: 9.4582 - mean_squared_error: 9.4582 - val_loss: 8.6019 - val_mean_squared_error: 8.6019
# Epoch 95/100
# 167/167 [==============================] - 2s 9ms/step - loss: 8.9225 - mean_squared_error: 8.9225 - val_loss: 9.2667 - val_mean_squared_error: 9.2667
# Epoch 96/100
# 167/167 [==============================] - 2s 10ms/step - loss: 8.9216 - mean_squared_error: 8.9216 - val_loss: 11.9068 - val_mean_squared_error: 11.9068
# Epoch 97/100
# 167/167 [==============================] - 1s 9ms/step - loss: 9.0146 - mean_squared_error: 9.0146 - val_loss: 8.7588 - val_mean_squared_error: 8.7588
# Epoch 98/100
# 167/167 [==============================] - 1s 9ms/step - loss: 8.7785 - mean_squared_error: 8.7785 - val_loss: 8.4456 - val_mean_squared_error: 8.4456
# Epoch 99/100
# 167/167 [==============================] - 1s 8ms/step - loss: 8.7478 - mean_squared_error: 8.7478 - val_loss: 8.4868 - val_mean_squared_error: 8.4868
# Epoch 100/100
# 167/167 [==============================] - 1s 8ms/step - loss: 8.8370 - mean_squared_error: 8.8370 - val_loss: 8.5768 - val_mean_squared_error: 8.5768

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model MSE Loss')  # 'model loss'를 'Model MSE Loss'로 변경
plt.ylabel('MSE Loss')  # y축 레이블을 'MSE Loss'로 변경
plt.xlabel('Epoch')  # x축 레이블은 'Epoch' 그대로 유지
plt.legend(['Train', 'Validation'], loc='upper left')  # 범례 그대로 유지
plt.show()

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

predy = model.predict(X_test)

mse = mean_squared_error(y_test, predy)
mae = mean_absolute_error(y_test, predy)
r2 = r2_score(y_test, predy)

print(f'MSE: {mse}')
print(f'MAE: {mae}')
print(f'R^2 Score: {r2}')

plt.scatter(y_test, predy, alpha=0.5)
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='red', linestyle='--')
plt.title('Actual vs Predicted')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
# Out:
# 17/27 [=================>............] - ETA: 0s
# 2024-09-30 18:13:26.812647: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 27/27 [==============================] - 1s 28ms/step
# MSE: 7.611179230521093
# MAE: 2.0771706218628
# R^2 Score: 0.23449931932571622
# Text(0, 0.5, 'Predicted Values')
