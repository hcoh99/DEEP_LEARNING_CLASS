# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## CSV파일 로드

# %%
df = pd.read_csv("/Users/ohheungchan/workspace/AI_Study/abalone.csv", index_col=0)
df
# Out:
#      Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  \
# id
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera_weight  Shell_weight  Rings
# id
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# 3             0.1140        0.1550     10
# 4             0.0395        0.0550      7
# ...              ...           ...    ...
# 4172          0.2390        0.2490     11
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4175          0.2610        0.2960     10
# 4176          0.3765        0.4950     12
#
# [4177 rows x 9 columns]

# %% [markdown]
# ## 결측치 확인

# %%
df.isnull().sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole_weight      0
# Shucked_weight    0
# Viscera_weight    0
# Shell_weight      0
# Rings             0
# dtype: int64

# %% [markdown]
# ## 이상치 확인

# %%
# 수치형 데이터 열만 선택
numeric_columns = df.select_dtypes(include=['float64', 'int64']).columns

# 박스플롯을 그리기 위한 설정
plt.figure(figsize=(15, 10))

# 각 변수에 대해 개별 박스플롯을 그립니다.
for i, column in enumerate(numeric_columns, 1):
    plt.subplot(3, 3, i)  # 3x3 grid로 subplot을 설정
    df.boxplot(column)
    plt.title(f'Boxplot of {column}')

# 레이아웃을 자동으로 조정하여 겹치지 않게 함
plt.tight_layout()

# 플롯을 출력
plt.show()

# %% [markdown]
# ### 컬럼 설명
#
# 1. **Sex**: 전복의 성별 (M: 수컷, F: 암컷, I: 새끼)
# 2. **Length**: 전복의 최대 길이 (밀리미터 단위)
# 3. **Diameter**: 전복의 지름, 길이에 수직인 측정치 (밀리미터 단위)
# 4. **Height**: 전복의 높이, 껍질 속 고기 포함 (밀리미터 단위)
# 5. **Whole weight**: 전복 전체의 무게 (그램 단위)
# 6. **Shucked weight**: 전복 고기의 무게 (그램 단위)
# 7. **Viscera weight**: 전복의 내장 무게, 출혈 후 측정 (그램 단위)
# 8. **Shell weight**: 건조 후 전복 껍질의 무게 (그램 단위)
# 9. **Rings**: 전복의 고리 수, 나이 추정의 기준 (+1.5년)

# %%
df.info
# Out:
# <bound method DataFrame.info of      Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  \
# id
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera_weight  Shell_weight  Rings
# id
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# 3             0.1140        0.1550     10
# 4             0.0395        0.0550      7
# ...              ...           ...    ...
# 4172          0.2390        0.2490     11
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4175          0.2610        0.2960     10
# 4176          0.3765        0.4950     12
#
# [4177 rows x 9 columns]>

# %%
df.columns
# Out:
# Index(['Sex', 'Length', 'Diameter', 'Height', 'Whole_weight', 'Shucked_weight',
#        'Viscera_weight', 'Shell_weight', 'Rings'],
#       dtype='object')

# %% [markdown]
# ### 인코딩 (문자->수치)

# %%
# 'Sex'컬럼의 F/M을 수치화
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()
df['Sex'] = label.fit_transform(df['Sex'])

# %% [markdown]
# (M->0, F->2, I->1)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# 카운트플롯 그리기
plt.figure(figsize=(10, 6))
sns.countplot(x='Rings', data=df, palette='Set3')
plt.title('Count of Each Rings Value', fontsize=16)
plt.xlabel('Rings', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.xticks(rotation=45)  # x축 값이 겹치지 않도록 회전
plt.show()
# Out:
# /var/folders/9x/8whwzmnj6z5bjc7_h1txd9_r0000gn/T/ipykernel_85300/2749004283.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Rings', data=df, palette='Set3')

# %% [markdown]
# ## 각 피쳐간의 상관관계를 확인.

# %%
df_corr=df.corr()

#히트맵
plt.figure(figsize=(10,10))
sns.set(font_scale=0.8)
sns.heatmap(df_corr, annot=True, cbar=False)
plt.show()

# %%
y = df["Rings"]
y
# Out:
# id
# 0       15
# 1        7
# 2        9
# 3       10
# 4        7
#         ..
# 4172    11
# 4173    10
# 4174     9
# 4175    10
# 4176    12
# Name: Rings, Length: 4177, dtype: int64

# %% [markdown]
# ## label값을 구간화
# - 연속데이터를 범주형으로 바꾸는 작업

# %%
print (df.columns)
df = df.drop(columns=['Sex']) # Sex 특성 제거

for ix in df.index :
    row = df.loc[ix]
    if row.Rings <= 8:
        df.loc[ix, 'Rings'] = 'young'
    elif row.Rings >= 11:
        df.loc[ix, 'Rings'] = 'old'
    elif row.Rings >=9 & row.Rings <= 10:
        df.loc[ix, 'Rings'] = 'medium'
        
df.head()
# Out:
# Index(['Sex', 'Length', 'Diameter', 'Height', 'Whole_weight', 'Shucked_weight',
#        'Viscera_weight', 'Shell_weight', 'Rings'],
#       dtype='object')
# /var/folders/9x/8whwzmnj6z5bjc7_h1txd9_r0000gn/T/ipykernel_85300/3874682361.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'old' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[ix, 'Rings'] = 'old'
#     Length  Diameter  Height  Whole_weight  Shucked_weight  Viscera_weight  \
# id
# 0    0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1    0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2    0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3    0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4    0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#     Shell_weight   Rings
# id
# 0          0.150     old
# 1          0.070   young
# 2          0.210  medium
# 3          0.155  medium
# 4          0.055   young

# %%
plt.bar("young", len(df[df['Rings'] == 'young']), label="young")
plt.bar("medium", len(df[df['Rings'] == 'medium']), label="medium")
plt.bar("old", len(df[df['Rings'] == 'old']), label="old")
plt.legend()
plt.show()

# %%
y = df['Rings']
y
# Out:
# id
# 0          old
# 1        young
# 2       medium
# 3       medium
# 4        young
#          ...
# 4172       old
# 4173    medium
# 4174    medium
# 4175    medium
# 4176       old
# Name: Rings, Length: 4177, dtype: object

# %%
x = df.drop("Rings" , axis = 1)
x
# Out:
#       Length  Diameter  Height  Whole_weight  Shucked_weight  Viscera_weight  \
# id
# 0      0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1      0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2      0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3      0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4      0.330     0.255   0.080        0.2050          0.0895          0.0395
# ...      ...       ...     ...           ...             ...             ...
# 4172   0.565     0.450   0.165        0.8870          0.3700          0.2390
# 4173   0.590     0.440   0.135        0.9660          0.4390          0.2145
# 4174   0.600     0.475   0.205        1.1760          0.5255          0.2875
# 4175   0.625     0.485   0.150        1.0945          0.5310          0.2610
# 4176   0.710     0.555   0.195        1.9485          0.9455          0.3765
#
#       Shell_weight
# id
# 0           0.1500
# 1           0.0700
# 2           0.2100
# 3           0.1550
# 4           0.0550
# ...            ...
# 4172        0.2490
# 4173        0.2605
# 4174        0.3080
# 4175        0.2960
# 4176        0.4950
#
# [4177 rows x 7 columns]

# %%
print(x.shape)
print(y.shape)
# Out:
# (4177, 7)
# (4177,)

# %%
import numpy as np

np.unique(y)
# Out:
# array(['medium', 'old', 'young'], dtype=object)

# %%
y.shape
# Out:
# (4177,)

# %% [markdown]
# ## split_sequence
# - 각 타임스텝에서 가장 빈번하게 나온 label을 해당 타임스텝의 label로 설정.

# %%
import numpy as np
from collections import Counter

# split_sequence 함수 
def split_sequence(sequence, labels, n_steps):
    X, y = list(), list()
    for i in range(len(sequence)):
        end_ix = i + n_steps
        if end_ix > len(sequence)-1:
            break
        
        # sequence에서 n_steps 크기만큼 데이터 추출
        seq_x = sequence[i:end_ix]
        
        # labels에서 n_steps 크기만큼 레이블 추출
        seq_y = labels[i:end_ix]
        
        # seq_y에서 가장 많이 등장한 레이블 선택
        most_common_label = Counter(seq_y).most_common(1)[0][0]
        
        # X와 y에 추가
        X.append(seq_x)
        y.append(most_common_label)
    
    return np.array(X), np.array(y)

# %%
# n_step 값 정의
n_step = 7

# X과 y을 시퀀스 형태로 변환
X, y = split_sequence(x,y,n_step)
print(f" data shape: {X.shape}, Labels shape: {y.shape}")
# Out:
#  data shape: (4170, 7, 7), Labels shape: (4170,)

# %%
print(y)
# Out:
# ['young' 'young' 'medium' ... 'medium' 'medium' 'medium']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=32)

X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, stratify=y_train, random_state=32)

X_train.shape, X_test.shape, y_train.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((2668, 7, 7), (834, 7, 7), (2668,), (834,), (668, 7, 7), (668,))

# %%
label_encoder = LabelEncoder()
y_train_encoded = label_encoder.fit_transform(y_train)
y_val_encoded = label_encoder.transform(y_val)
y_test_encoded = label_encoder.transform(y_test)

# %%
from tensorflow.keras.utils import to_categorical

trainy_one_hot = to_categorical(y_train_encoded)
val_one_hot = to_categorical(y_val_encoded)
testy_one_hot = to_categorical(y_test_encoded)

# %%
n_timesteps, n_features = X_train.shape[1], X_train.shape[2]

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, Dense, Dropout, Flatten, Reshape, LSTM, Conv1D, MaxPooling1D, Bidirectional, ConvLSTM1D
# Model 3
model = Sequential()
model.add(Conv1D(filters=32, kernel_size=3, activation='relu', input_shape=(n_timesteps, n_features)))
model.add((Dropout(0.5)))
model.add(Conv1D(filters=64, kernel_size=3, activation='relu', padding='same'))
model.add((Dropout(0.5)))
model.add(Conv1D(filters=32, kernel_size=3, activation='relu', padding='same'))
model.add((Dropout(0.5)))
model.add(Flatten())
model.add(Dense(16, activation='relu'))
model.add(Dense(3, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_3 (Conv1D)           (None, 5, 32)             704
#
#  dropout_3 (Dropout)         (None, 5, 32)             0
#
#  conv1d_4 (Conv1D)           (None, 5, 64)             6208
#
#  dropout_4 (Dropout)         (None, 5, 64)             0
#
#  conv1d_5 (Conv1D)           (None, 5, 32)             6176
#
#  dropout_5 (Dropout)         (None, 5, 32)             0
#
#  flatten_1 (Flatten)         (None, 160)               0
#
#  dense_2 (Dense)             (None, 16)                2576
#
#  dense_3 (Dense)             (None, 3)                 51
#
# =================================================================
# Total params: 15,715
# Trainable params: 15,715
# Non-trainable params: 0
# _________________________________________________________________

# %%
batch_size = 16

train_epochs = 50
history = model.fit(X_train, trainy_one_hot, epochs=train_epochs, batch_size=batch_size, validation_data=(X_val, val_one_hot), verbose=True, shuffle=True)
# Out:
# Epoch 1/50
# 2024-09-26 09:55:07.320063: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 167/167 [==============================] - ETA: 0s - loss: 1.0326 - accuracy: 0.4164
# 2024-09-26 09:55:09.800398: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 167/167 [==============================] - 3s 16ms/step - loss: 1.0326 - accuracy: 0.4164 - val_loss: 0.9010 - val_accuracy: 0.5449
# Epoch 2/50
# 167/167 [==============================] - 2s 13ms/step - loss: 0.8746 - accuracy: 0.5585 - val_loss: 0.8244 - val_accuracy: 0.6033
# Epoch 3/50
# 167/167 [==============================] - 2s 13ms/step - loss: 0.8315 - accuracy: 0.5892 - val_loss: 0.7806 - val_accuracy: 0.6557
# Epoch 4/50
# 167/167 [==============================] - 2s 13ms/step - loss: 0.7635 - accuracy: 0.6398 - val_loss: 0.6947 - val_accuracy: 0.7081
# Epoch 5/50
# 167/167 [==============================] - 2s 13ms/step - loss: 0.7079 - accuracy: 0.6874 - val_loss: 0.6461 - val_accuracy: 0.7500
# Epoch 6/50
# 167/167 [==============================] - 2s 13ms/step - loss: 0.6599 - accuracy: 0.7133 - val_loss: 0.6399 - val_accuracy: 0.7171
# Epoch 7/50
# 167/167 [==============================] - 2s 13ms/step - loss: 0.6382 - accuracy: 0.7286 - val_loss: 0.6024 - val_accuracy: 0.7530
# Epoch 8/50
# 167/167 [==============================] - 2s 13ms/step - loss: 0.6277 - accuracy: 0.7129 - val_loss: 0.6282 - val_accuracy: 0.7335
# Epoch 9/50
# 167/167 [==============================] - 2s 13ms/step - loss: 0.6194 - accuracy: 0.7275 - val_loss: 0.6091 - val_accuracy: 0.7320
# Epoch 10/50
# 167/167 [==============================] - 2s 13ms/step - loss: 0.6122 - accuracy: 0.7459 - val_loss: 0.5906 - val_accuracy: 0.7545
# Epoch 11/50
# 167/167 [==============================] - 2s 13ms/step - loss: 0.6014 - accuracy: 0.7309 - val_loss: 0.5857 - val_accuracy: 0.7470
# Epoch 12/50
# 167/167 [==============================] - 2s 13ms/step - loss: 0.5926 - accuracy: 0.7324 - val_loss: 0.5878 - val_accuracy: 0.7440
# Epoch 13/50
# 167/167 [==============================] - 2s 13ms/step - loss: 0.6088 - accuracy: 0.7230 - val_loss: 0.5773 - val_accuracy: 0.7575
# Epoch 14/50
# 167/167 [==============================] - 2s 13ms/step - loss: 0.5879 - accuracy: 0.7365 - val_loss: 0.5715 - val_accuracy: 0.7485
# Epoch 15/50
# 167/167 [==============================] - 2s 13ms/step - loss: 0.5897 - accuracy: 0.7369 - val_loss: 0.6039 - val_accuracy: 0.7320
# Epoch 16/50
# 167/167 [==============================] - 2s 13ms/step - loss: 0.5850 - accuracy: 0.7459 - val_loss: 0.5874 - val_accuracy: 0.7335
# Epoch 17/50
# 167/167 [==============================] - 2s 13ms/step - loss: 0.5708 - accuracy: 0.7418 - val_loss: 0.5831 - val_accuracy: 0.7500
# Epoch 18/50
# 167/167 [==============================] - 2s 13ms/step - loss: 0.5703 - accuracy: 0.7448 - val_loss: 0.5957 - val_accuracy: 0.7320
# Epoch 19/50
# 167/167 [==============================] - 2s 13ms/step - loss: 0.5705 - accuracy: 0.7455 - val_loss: 0.5585 - val_accuracy: 0.7530
# Epoch 20/50
# 167/167 [==============================] - 2s 13ms/step - loss: 0.5702 - accuracy: 0.7451 - val_loss: 0.5803 - val_accuracy: 0.7485
# Epoch 21/50
# 167/167 [==============================] - 2s 13ms/step - loss: 0.5703 - accuracy: 0.7549 - val_loss: 0.5497 - val_accuracy: 0.7560
# Epoch 22/50
# 167/167 [==============================] - 2s 14ms/step - loss: 0.5681 - accuracy: 0.7481 - val_loss: 0.5786 - val_accuracy: 0.7440
# Epoch 23/50
# 167/167 [==============================] - 2s 13ms/step - loss: 0.5473 - accuracy: 0.7455 - val_loss: 0.5473 - val_accuracy: 0.7620
# Epoch 24/50
# 167/167 [==============================] - 2s 13ms/step - loss: 0.5537 - accuracy: 0.7478 - val_loss: 0.5804 - val_accuracy: 0.7350
# Epoch 25/50
# 167/167 [==============================] - 2s 13ms/step - loss: 0.5652 - accuracy: 0.7463 - val_loss: 0.6066 - val_accuracy: 0.7410
# Epoch 26/50
# 167/167 [==============================] - 2s 13ms/step - loss: 0.5518 - accuracy: 0.7556 - val_loss: 0.5732 - val_accuracy: 0.7425
# Epoch 27/50
# 167/167 [==============================] - 2s 13ms/step - loss: 0.5493 - accuracy: 0.7601 - val_loss: 0.5789 - val_accuracy: 0.7395
# Epoch 28/50
# 167/167 [==============================] - 2s 13ms/step - loss: 0.5546 - accuracy: 0.7504 - val_loss: 0.6334 - val_accuracy: 0.7246
# Epoch 29/50
# 167/167 [==============================] - 2s 13ms/step - loss: 0.5455 - accuracy: 0.7507 - val_loss: 0.5363 - val_accuracy: 0.7650
# Epoch 30/50
# 167/167 [==============================] - 2s 13ms/step - loss: 0.5498 - accuracy: 0.7590 - val_loss: 0.5598 - val_accuracy: 0.7635
# Epoch 31/50
# 167/167 [==============================] - 2s 13ms/step - loss: 0.5433 - accuracy: 0.7601 - val_loss: 0.5559 - val_accuracy: 0.7590
# Epoch 32/50
# 167/167 [==============================] - 2s 13ms/step - loss: 0.5427 - accuracy: 0.7485 - val_loss: 0.5808 - val_accuracy: 0.7440
# Epoch 33/50
# 167/167 [==============================] - 2s 13ms/step - loss: 0.5432 - accuracy: 0.7564 - val_loss: 0.6234 - val_accuracy: 0.7275
# Epoch 34/50
# 167/167 [==============================] - 2s 13ms/step - loss: 0.5413 - accuracy: 0.7500 - val_loss: 0.5956 - val_accuracy: 0.7246
# Epoch 35/50
# 167/167 [==============================] - 2s 14ms/step - loss: 0.5261 - accuracy: 0.7676 - val_loss: 0.5908 - val_accuracy: 0.7365
# Epoch 36/50
# 167/167 [==============================] - 2s 14ms/step - loss: 0.5420 - accuracy: 0.7552 - val_loss: 0.5832 - val_accuracy: 0.7380
# Epoch 37/50
# 167/167 [==============================] - 2s 14ms/step - loss: 0.5390 - accuracy: 0.7669 - val_loss: 0.5234 - val_accuracy: 0.7575
# Epoch 38/50
# 167/167 [==============================] - 2s 14ms/step - loss: 0.5299 - accuracy: 0.7582 - val_loss: 0.5505 - val_accuracy: 0.7320
# Epoch 39/50
# 167/167 [==============================] - 2s 14ms/step - loss: 0.5341 - accuracy: 0.7579 - val_loss: 0.5531 - val_accuracy: 0.7695
# Epoch 40/50
# 167/167 [==============================] - 2s 14ms/step - loss: 0.5268 - accuracy: 0.7672 - val_loss: 0.6749 - val_accuracy: 0.6781
# Epoch 41/50
# 167/167 [==============================] - 2s 13ms/step - loss: 0.5451 - accuracy: 0.7556 - val_loss: 0.5604 - val_accuracy: 0.7485
# Epoch 42/50
# 167/167 [==============================] - 2s 13ms/step - loss: 0.5236 - accuracy: 0.7654 - val_loss: 0.5344 - val_accuracy: 0.7605
# Epoch 43/50
# 167/167 [==============================] - 2s 13ms/step - loss: 0.5268 - accuracy: 0.7714 - val_loss: 0.5817 - val_accuracy: 0.7305
# Epoch 44/50
# 167/167 [==============================] - 2s 13ms/step - loss: 0.5354 - accuracy: 0.7541 - val_loss: 0.5496 - val_accuracy: 0.7575
# Epoch 45/50
# 167/167 [==============================] - 2s 13ms/step - loss: 0.5310 - accuracy: 0.7620 - val_loss: 0.5280 - val_accuracy: 0.7620
# Epoch 46/50
# 167/167 [==============================] - 2s 13ms/step - loss: 0.5252 - accuracy: 0.7597 - val_loss: 0.5589 - val_accuracy: 0.7395
# Epoch 47/50
# 167/167 [==============================] - 2s 14ms/step - loss: 0.5297 - accuracy: 0.7657 - val_loss: 0.5512 - val_accuracy: 0.7515
# Epoch 48/50
# 167/167 [==============================] - 2s 13ms/step - loss: 0.5249 - accuracy: 0.7627 - val_loss: 0.5812 - val_accuracy: 0.7231
# Epoch 49/50
# 167/167 [==============================] - 2s 14ms/step - loss: 0.5201 - accuracy: 0.7616 - val_loss: 0.5743 - val_accuracy: 0.7305
# Epoch 50/50
# 167/167 [==============================] - 2s 13ms/step - loss: 0.5182 - accuracy: 0.7676 - val_loss: 0.5513 - val_accuracy: 0.7246

# %%
import matplotlib.pyplot as plt
import seaborn as sns

loss =history.history['loss']
val_loss =history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
acc =history.history['accuracy']
val_acc =history.history['val_accuracy']
plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score
from sklearn.metrics import f1_score, classification_report
predy=model.predict(X_test)
predy=np.argmax(predy, axis=-1)
LABELS = ['Young', 'Middle-aged', 'Old']
cm=confusion_matrix(y_test_encoded,predy)
print(cm)
print(accuracy_score(y_test_encoded,predy))
print(f1_score(y_test_encoded,predy, average='weighted'))
print(classification_report(y_test_encoded,predy))
sns.heatmap(cm, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt = '.2f')
# Out:
# 24/27 [=========================>....] - ETA: 0s
# 2024-09-26 09:58:49.462065: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 27/27 [==============================] - 0s 7ms/step
# [[208  17  28]
#  [121 186   4]
#  [ 57  14 199]]
# 0.7110311750599521
# 0.7174004910914565
#               precision    recall  f1-score   support
#
#            0       0.54      0.82      0.65       253
#            1       0.86      0.60      0.70       311
#            2       0.86      0.74      0.79       270
#
#     accuracy                           0.71       834
#    macro avg       0.75      0.72      0.72       834
# weighted avg       0.76      0.71      0.72       834
# <Axes: >
